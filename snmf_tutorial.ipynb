# %%
from llm_utils.activation_generator import ActivationGenerator
from data_utils.concept_dataset import SupervisedConceptDataset
import random
import numpy as np
import torch

# %%
if torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")
# Out:
# Device: mps

# %%
# path to data
data_path = "data/languages.json"

# name of model, must be supported by transformer lens
model_name = "gpt2-large"

# layers of model to inspect
layers = [0]

# Device to load data to, default is CPU and only factorization and generation occurs on GPU
data_device = 'cpu'

# Device to load model to for generation
model_device = device

# factorization mode, factorize residual or mlp layers
factorization_mode = 'mlp'

# %%
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # For multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False  # Ensures deterministic behavior

set_seed(42)

# %%
act_generator = ActivationGenerator(model_name, model_device=model_device, data_device=data_device, mode=factorization_mode)
# Out:
# Loaded pretrained model gpt2-large into HookedTransformer

# %%
dataset = SupervisedConceptDataset(data_path)

# %%
activations, freq = act_generator.generate_multiple_layer_activations_and_freq(dataset, layers)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Building vocab frequency: 100%|██████████| 40/40 [00:00<00:00, 2378.70it/s]
# Generating multi-layer activations with freq: 100%|██████████| 40/40 [00:04<00:00,  9.04it/s]

# %%
# model parameters
rank = 100 # number of features
nmf_device = 'mps' # your GPU
fitting_device = device # your GPU
max_iterations = 20000 # has early stopping this is just the max
epoch_to_epoch_tol = 1e-6 # diff. in training objective that we tolerate (if smaller we end training)
# set above to negative if don't want early stopping
lr = 1e-3 # 1e-2 till 1e-4 works well (lower is just slower)

# %%
from factorization.seminmf import NMFSemiNMF
# sparsity is percent of neurons to use in final features
nmf = NMFSemiNMF(rank, fitting_device=fitting_device, sparsity=0.01)

# patience is how many epochs to wait for loss to improve
# init can be svd and knn too, in terms of performance they are all the same
# we need to tranpose activations to match literature's (dimensio, num_samples)
# we take activations[0] since its a list of activations (index for every layer you used when generating)
nmf.fit(activations[0].T, max_iterations, patience=500)
# Out:
# Iter    0: loss=433303.062500  (best=433303.062500, no_improve=0)
# Iter    2: loss=421583.531250  (best=419733.562500, no_improve=1)
# Iter   50: loss=313503.625000  (best=313503.625000, no_improve=0)
# Iter   77: loss=309093.375000  (best=309070.500000, no_improve=1)
# Iter   79: loss=309001.593750  (best=308987.125000, no_improve=1)
# Iter   86: loss=308424.250000  (best=308390.562500, no_improve=1)
# Iter   93: loss=308316.343750  (best=308281.562500, no_improve=1)
# Iter   99: loss=308084.093750  (best=308042.687500, no_improve=1)
# Iter  100: loss=307962.343750  (best=307962.343750, no_improve=0)
# Iter  103: loss=307909.593750  (best=307873.906250, no_improve=1)
# Iter  118: loss=306833.500000  (best=306824.781250, no_improve=1)
# Iter  124: loss=306727.812500  (best=306672.468750, no_improve=1)
# Iter  135: loss=306178.656250  (best=306120.343750, no_improve=1)
# Iter  139: loss=306055.375000  (best=306034.656250, no_improve=1)
# Iter  150: loss=305234.625000  (best=305207.312500, no_improve=1)
# Iter  159: loss=305002.718750  (best=304989.593750, no_improve=1)
# Iter  163: loss=304917.187500  (best=304903.312500, no_improve=1)
# Iter  171: loss=304849.718750  (best=304842.906250, no_improve=1)
# Iter  173: loss=304800.031250  (best=304798.937500, no_improve=1)
# Iter  177: loss=304759.625000  (best=304736.437500, no_improve=1)
# Iter  182: loss=304651.812500  (best=304625.843750, no_improve=1)
# Iter  187: loss=304504.593750  (best=304499.812500, no_improve=1)
# Iter  189: loss=304488.218750  (best=304477.781250, no_improve=1)
# Iter  197: loss=304355.718750  (best=304342.750000, no_improve=1)
# Iter  200: loss=304273.375000  (best=304273.375000, no_improve=0)
# Iter  201: loss=304288.250000  (best=304273.375000, no_improve=1)
# Iter  203: loss=304326.718750  (best=304271.781250, no_improve=1)
# Iter  212: loss=304175.812500  (best=304169.343750, no_improve=1)
# Iter  219: loss=304158.062500  (best=304153.562500, no_improve=1)
# Iter  246: loss=304153.562500  (best=304143.500000, no_improve=1)
# Iter  250: loss=304178.843750  (best=304143.500000, no_improve=5)
# Iter  256: loss=304192.781250  (best=304126.437500, no_improve=1)
# Iter  287: loss=304143.093750  (best=304102.250000, no_improve=1)
# Iter  300: loss=304144.000000  (best=304102.250000, no_improve=14)
# Iter  350: loss=304207.406250  (best=304102.250000, no_improve=64)
# Iter  400: loss=304113.218750  (best=304102.250000, no_improve=114)
# Iter  431: loss=304098.812500  (best=304098.812500, no_improve=1)
# Iter  437: loss=304097.031250  (best=304097.031250, no_improve=1)
# Iter  450: loss=304106.687500  (best=304097.031250, no_improve=14)
# Iter  455: loss=304064.406250  (best=304064.406250, no_improve=1)
# Iter  463: loss=304061.375000  (best=304058.468750, no_improve=1)
# Iter  473: loss=304057.500000  (best=304049.781250, no_improve=1)
# Iter  482: loss=304048.656250  (best=304045.218750, no_improve=1)
# Iter  497: loss=304041.593750  (best=304041.531250, no_improve=1)
# Iter  500: loss=304055.937500  (best=304041.531250, no_improve=4)
# Iter  519: loss=304011.906250  (best=304010.718750, no_improve=1)
# Iter  532: loss=304005.343750  (best=304005.250000, no_improve=1)
# Iter  540: loss=304000.593750  (best=303979.468750, no_improve=1)
# Iter  550: loss=304004.031250  (best=303979.468750, no_improve=11)
# Iter  600: loss=nan  (best=303979.468750, no_improve=61)
# Iter  650: loss=nan  (best=303979.468750, no_improve=111)
# Iter  700: loss=nan  (best=303979.468750, no_improve=161)
# Iter  750: loss=nan  (best=303979.468750, no_improve=211)
# Iter  800: loss=nan  (best=303979.468750, no_improve=261)
# Iter  850: loss=nan  (best=303979.468750, no_improve=311)
# Iter  900: loss=nan  (best=303979.468750, no_improve=361)
# Iter  950: loss=nan  (best=303979.468750, no_improve=411)
# Iter 1000: loss=nan  (best=303979.468750, no_improve=461)
# Stopping early at iter 1039 (no improvement in 500 iters)
# NMFSemiNMF()

# %% [markdown]
# #### Utils for interpreting features

# %%
def get_top_activating_indices(W, concept_idx, num_samples=10, minimal_activation=0):
    activations = []
    non_zero_indices = []

    sample_importance = W[:, concept_idx]
    # Get indices of the top samples (highest activation values)
    top_indices = np.argsort(sample_importance)[-num_samples:]
    for i in top_indices:
        act = sample_importance[i]
        if act <= 0:
            continue
        activations.append(act)
        non_zero_indices.append(i)
   
    return non_zero_indices, activations

def print_logit_diff(model, logits_before, logits_after, top_k=10):
    """
    Print the tokens with the largest positive and negative logit changes
    after some intervention.

    Args:
      model         : object with `to_str_tokens(torch.LongTensor)->List[str]`
      logits_before : torch.Tensor, shape (1, seq_len, vocab_size)
      logits_after  : torch.Tensor, shape (1, seq_len, vocab_size)
      top_k         : int, how many tokens to show in each category
    """
    # compute delta for the last position
    delta = logits_after[0, -1, :] - logits_before[0, -1, :]

    # top positive changes
    pos_vals, pos_idx = torch.topk(delta, k=top_k, largest=True)
    # top negative changes
    neg_vals, neg_idx = torch.topk(delta, k=top_k, largest=False)

    print(f"Top {top_k} ↑ logit changes:")
    for token_id, change in zip(pos_idx.tolist(), pos_vals.tolist()):
        ids = torch.tensor([token_id], dtype=torch.long, device=delta.device)
        token_str = model.to_str_tokens(ids)[0]
        print(f"  {token_str:>12}   {change:+.4f}")

    print(f"\nTop {top_k} ↓ logit changes:")
    for token_id, change in zip(neg_idx.tolist(), neg_vals.tolist()):
        ids = torch.tensor([token_id], dtype=torch.long, device=delta.device)
        token_str = model.to_str_tokens(ids)[0]
        print(f"  {token_str:>12}   {change:+.4f}")


def get_logit_diff(model, logits_before, logits_after, top_k=20, magnitude=False):
    """
    Return a list of token strings and their logit changes.

    Args:
      model         : object with `to_str_tokens(torch.LongTensor) -> List[str]`
      logits_before : torch.Tensor, shape (1, seq_len, vocab_size)
      logits_after  : torch.Tensor, shape (1, seq_len, vocab_size)
      top_k         : int, how many tokens to return
      magnitude     : bool, if True rank by abs(delta), else by signed delta

    Returns:
      List[str], e.g. ["Token: 'hello', Score: 2.3456", …]
    """
    delta = logits_after[0, -1, :] - logits_before[0, -1, :]
    if magnitude:
        scores, idx = torch.topk(delta.abs(), k=top_k)
    else:
        scores, idx = torch.topk(delta, k=top_k)

    results = []
    for token_id, score in zip(idx.tolist(), scores.tolist()):
        ids_tensor = torch.tensor([token_id], dtype=torch.long, device=logits_before.device)
        token_strs = model.to_str_tokens(ids_tensor)
        results.append(f"Token: {token_strs[0]}, Score: {score:.4f}")
    return results

# %% [markdown]
# #### Helper function to extract the tokens and labels for interpreting features

# %%
from llm_utils.activation_generator import extract_token_ids_sample_ids_and_labels

tokens, sample_ids, labels = extract_token_ids_sample_ids_and_labels(dataset, act_generator)
# Out:
# Extracting token IDs: 100%|██████████| 40/40 [00:00<00:00, 378.25it/s]

# %% [markdown]
# #### Helper function to get token contexts
# So we see the contexts and not just the token whose activation was activated

# %%
def generate_token_contexts(tokens, sample_ids, act_generator):
    # Define how many tokens before and after to include in the context
    context_window = 15

    token_ds = []
    for i in range(len(tokens)):
        current_sample_id = sample_ids[i]
        # Convert the current token to its string representation
        token_str = act_generator.model.to_str_tokens([tokens[i]])[0][0]
        
        # Determine the start and end indices for the context window
        start = max(0, i - context_window)
        end = min(len(tokens), i + context_window + 1)
        
        # Get the string representation for each token in the context
        context_tokens = [
            act_generator.model.to_str_tokens([tokens[j]])[0][0] for j in range(start, end) if sample_ids[j] == current_sample_id
        ]
        
        # Join the context tokens into a single string
        context_str = "".join(context_tokens)
        
        # Append the (token, context) tuple to the list
        token_ds.append((token_str, context_str))

    return token_ds

token_ds = generate_token_contexts(tokens, sample_ids, act_generator)

# %% [markdown]
# #### Prints for the first 50 features their activating token, activation strengh, context

# %%
for k in range(50):
    ti, ta = get_top_activating_indices(nmf.G_.cpu().detach(), k, 40)
    top_activations = [{'token': token_ds[i][0], 'activation': a, 'context': token_ds[i][1]} for i, a in zip(ti, ta)]
    print(f"###########{k}#############\n")
    for idx, i in enumerate(ti):
        print(f"{token_ds[i][0]}\t\t{ta[idx]}\t\t{token_ds[i][1]}")
# Out:
# ###########0#############
#
#  delve		0.08781487494707108		Studying Russian allows one to delve into rich historical narratives and cultural identity.
#  showcase		0.08865290880203247		Festivals like La Tomatina showcase the lively and communal spirit of the Spanish language.
#  reflect		0.08917690068483353		Korean grammar features honorifics and specific sentence structures that reflect social hierarchy.
#  reflect		0.09268040955066681		Regional variations in Spanish reflect the rich cultural diversity of its speakers.
#  reflect		0.0935516282916069		Russian idioms and proverbs often reflect the resilience and spirit of its people.
#  reflect		0.0984116718173027		Traditional German idioms reflect the practical wisdom and humor of its speakers.
#  reveal		0.09979917854070663		Ancient Hebrew inscriptions discovered at archaeological sites reveal rich history.
#  become		0.09992419928312302		Many Spanish phrases have become part of everyday international vocabulary.
#  derive		0.10164395719766617		Idiomatic expressions in Chinese, like 'Chengyu', often derive from historical tales.
#  carry		0.10505453497171402		Many Hebrew expressions carry deep spiritual and historical significance.
#  illustrate		0.10551442205905914		Various Arabic dialects illustrate the diversity and cultural depth of the Middle East.
#  highlight		0.1056680828332901		Festivals across Russia highlight the cultural importance of its language.
#  highlight		0.10691028088331223		Festivals in China often highlight ancient customs and the beauty of the Chinese language.
#  highlight		0.10771302133798599		Regional variations in French highlight the diverse cultural landscape of France.
#  highlight		0.10909803211688995		Traditional festivals in Japan often highlight the beauty of its language and customs.
#  inspire		0.11082476377487183		Italian poetry and prose continue to inspire creative expression worldwide.
#  exist		0.11210697144269943		Many dialects exist in Chinese, with Mandarin and Cantonese being among the most recognized.
#  be		0.1221260130405426		Learning Russian can be an enriching journey through a storied past and vibrant present.
#  be		0.12336920201778412		The influence of Chinese language and culture can be seen in art, cuisine, and traditions worldwide.
#  continue		0.12972941994667053		Italian poetry and prose continue to inspire creative expression worldwide.
#  are		0.12980197370052338		Italy��s rich art and architecture are closely tied to its expressive language.
#  make		0.13427720963954926		The structural differences between Chinese and Western languages make learning it an adventure.
#  continue		0.134902223944664		Technological advancements continue to shape modern Chinese slang and expressions.
#  are		0.1404731720685959		Many Chinese idioms are intertwined with natural imagery and philosophical insights.
#  are		0.14204928278923035		Latin roots are deeply embedded in Italian, giving it a timeless quality.
#  are		0.14310677349567413		Numerous ancient manuscripts and texts are written in the Hebrew language.
#  attract		0.14370185136795044		Globally, Spanish language courses attract learners with their cultural allure.
#  attract		0.14384306967258453		Language classes in Hebrew attract those fascinated by both history and contemporary culture.
#  are		0.14409783482551575		University courses in Chinese are increasingly popular as global interest grows.
#  provide		0.14440974593162537		Ancient Chinese texts provide unique insights into the philosophies of old.
#  are		0.14836710691452026		Arabic music and poetry are celebrated worldwide for their emotive power and lyrical beauty.
#  are		0.15088002383708954		Traditional Arabic proverbs are steeped in history and cultural wisdom.
#  are		0.1513080596923828		Russian art, music, and literature are deeply interwoven with its language.
#  are		0.15469954907894135		Chinese proverbs are renowned for their wisdom and concise expressions of life lessons.
#  are		0.15505021810531616		Fashion and art in France are closely linked to the sophistication of its language.
#  attract		0.1564938873052597		Russian language courses attract those eager to explore Eastern European history.
#  have		0.16011390089988708		Popular Korean films and dramas have introduced many to the nuances of the language.
#  have		0.16647017002105713		Many Spanish phrases have become part of everyday international vocabulary.
#  have		0.1699916422367096		Classical Arabic texts have shaped philosophical and scientific thought over centuries.
#  have		0.1787175089120865		Literary giants such as Goethe and Schiller have made German a language of high art.
# ###########1#############
#
#  Cant		0.030348455533385277		Many dialects exist in Chinese, with Mandarin and Cantonese being among the most recognized.
#  dialect		0.030435090884566307		Many dialects exist in Chinese, with Mandarin and Cantonese being among the most
#  vocabulary		0.034207750111818314		Many Spanish phrases have become part of everyday international vocabulary.
#  vocabulary		0.036293309181928635		The impact of German on scientific and technical vocabulary is evident worldwide.
#  vocabulary		0.040296521037817		The expansive vocabulary of Arabic allows speakers to articulate complex ideas poetically.
#  slang		0.043290115892887115		Modern Korean artfully blends traditional expressions with contemporary slang.
#  slang		0.043759848922491074		Modern Italian seamlessly blends traditional expressions with contemporary slang.
#  slang		0.044715601950883865		Modern German skillfully blends classical expressions with new, innovative slang.
#  slang		0.045015133917331696		Modern Russian successfully blends time-honored expressions with evolving slang.
#  idi		0.0459563247859478		Common Hebrew idioms encapsulate centuries of cultural wisdom.
#  lex		0.04676680639386177		New words and expressions continuously shape the modern Korean lexicon.
#  rules		0.047116637229919434		The grammar of Arabic, with its intricate rules, presents a fascinating linguistic challenge.
#  slang		0.047362666577100754		Technological advancements continue to shape modern Chinese slang and expressions.
#  idi		0.04766717925667763		Traditional German idioms reflect the practical wisdom and humor of its speakers.
#  idi		0.04782178997993469		Common Spanish idioms encapsulate centuries of cultural experience.
#  idi		0.04784988611936569		Common Italian idioms capture the warmth and charm of everyday life.
#  slang		0.04823989048600197		Modern Spanish continually evolves with new slang and contemporary expressions.
#  idi		0.051281191408634186		Russian idioms and proverbs often reflect the resilience and spirit of its people.
#  idi		0.05134544521570206		Many Chinese idioms are intertwined with natural imagery and philosophical insights.
#  linguistic		0.05137772113084793		The revival of modern Hebrew in the 19th century stands as a remarkable linguistic achievement.
#  idi		0.05158770829439163		Traditional idioms in Japanese often express cultural values and historical narratives.
#  noun		0.05248494818806648		The intricacies of Spanish grammar, with its gendered nouns and verb conjugations, present a delightful challenge.
# Liter		0.0535864420235157		Literary giants such as Goethe and Schiller have made German a language of
#  noun		0.05388260632753372		German grammar, with its cases and gendered nouns, presents a fascinating linguistic structure.
#  idi		0.05429012328386307		French idioms capture subtle emotions and a nuanced cultural history.
#  linguistic		0.05782730504870415		German grammar, with its cases and gendered nouns, presents a fascinating linguistic structure.
#  linguistic		0.059474196285009384		The grammar of Arabic, with its intricate rules, presents a fascinating linguistic challenge.
#  Cyr		0.05977809429168701		The Cyrillic alphabet gives Russian its unique written character and visual appeal.
#  pronunciation		0.0611419677734375		The lyrical pronunciation of Italian makes every conversation sound like music.
#  pronunciation		0.061142321676015854		The lyrical pronunciation of Spanish adds beauty to its spoken word.
#  Garc		0.06153763085603714		Spanish literature is enriched by classics from Cervantes to Gabriel García Márquez.
#  pronunciation		0.06430699676275253		The elegant pronunciation of French gives the language its unique charm.
#  phon		0.06853209435939789		Hangul is admired for its simplicity, phonetic design, and visual harmony.
#  grammar		0.34366104006767273		Renowned for its precise grammar, French is a language of refined expression.
#  grammar		0.34407559037208557		The intricacies of Spanish grammar, with its gendered nouns and verb conjugations, present a
#  grammar		0.34849753975868225		The structure of Japanese grammar presents unique challenges and rewards for learners.
#  grammar		0.3531912565231323		German grammar, with its cases and gendered nouns, presents a fascinating linguistic structure
#  grammar		0.35431504249572754		The complex grammar of Russian—with its cases and declensions—offers an intriguing challenge
#  grammar		0.35500383377075195		Korean grammar features honorifics and specific sentence structures that reflect social hierarchy.
#  grammar		0.3598043620586395		The grammar of Arabic, with its intricate rules, presents a fascinating linguistic challenge.
# ###########2#############
#
#  Arabic		0.01932941935956478		Traditional Arabic proverbs are steeped in history and cultural wisdom.
#  Arabic		0.019426856189966202		Diverse Arabic dialects add to the region's vibrant cultural mosaic.
#  and		0.019454339519143105		Many Hebrew expressions carry deep spiritual and historical significance.
#  noun		0.019792811945080757		The intricacies of Spanish grammar, with its gendered nouns and verb conjugations, present a delightful challenge.
#  Arabic		0.020015383139252663		Learning Arabic provides a gateway to understanding Islamic history and traditions.
# verbs		0.02045094408094883		Timeless French proverbs offer a glimpse into the nation's enduring wisdom.
#  noun		0.020702004432678223		German grammar, with its cases and gendered nouns, presents a fascinating linguistic structure.
# verbs		0.02176356501877308		Russian idioms and proverbs often reflect the resilience and spirit of its people.
# verbs		0.02211778797209263		Traditional Korean proverbs offer wisdom that has been passed down through generations.
# verbs		0.023054473102092743		Traditional Spanish proverbs offer timeless insights into life and culture.
# verbs		0.023188438266515732		Traditional Russian proverbs offer a window into the values and hardships of its past.
#  Arabic		0.02320866473019123		The Arabic language has enriched many other languages through loanwords and expressions.
# verbs		0.023470258340239525		Chinese proverbs are renowned for their wisdom and concise expressions of life lessons.
# verbs		0.024149451404809952		Many Japanese proverbs convey deep cultural wisdom and life lessons.
#  Mandarin		0.024309340864419937		Many dialects exist in Chinese, with Mandarin and Cantonese being among the most recognized.
# verbs		0.024799000471830368		Traditional Arabic proverbs are steeped in history and cultural wisdom.
#  the		0.025242110714316368		The revival of modern Hebrew in the 19th century stands as a remarkable linguistic achievement.
#  a		0.03662976250052452		As the official language of Israel, Hebrew is a cornerstone of national identity.
# Ha		0.038319725543260574		Haiku, a classic form of Japanese poetry, captures the essence of nature in
#  scriptures		0.05328409746289253		Hebrew literature spans from timeless scriptures to modern novels.
#  biblical		0.08292780071496964		Studying Hebrew offers valuable insights into biblical narratives and ancient customs.
#  Jewish		0.09009319543838501		Hebrew plays a crucial role in Jewish religious texts and traditions.
#  Israel		0.09474164247512817		As the official language of Israel, Hebrew is a cornerstone of national identity.
#  Israel		0.09580502659082413		The renaissance of Hebrew was pivotal in shaping the cultural fabric of Israel.
#  Israelis		0.10258674621582031		Everyday conversation in Hebrew connects modern Israelis with their ancestral roots.
#  Hebrew		0.23572765290737152		Numerous ancient manuscripts and texts are written in the Hebrew language.
#  Hebrew		0.23707064986228943		Language classes in Hebrew attract those fascinated by both history and contemporary culture.
#  Hebrew		0.2412569522857666		As the official language of Israel, Hebrew is a cornerstone of national identity.
#  Hebrew		0.24133431911468506		Ancient Hebrew inscriptions discovered at archaeological sites reveal rich history.
#  Hebrew		0.24257203936576843		Over the millennia, Hebrew has merged ancient tradition with modern usage.
#  Hebrew		0.24280224740505219		Written from right to left, the Hebrew script is both elegant and distinctive.
#  Hebrew		0.2429235577583313		Studying Hebrew offers valuable insights into biblical narratives and ancient customs.
#  Hebrew		0.24366390705108643		Everyday conversation in Hebrew connects modern Israelis with their ancestral roots.
#  Hebrew		0.24419452250003815		Common Hebrew idioms encapsulate centuries of cultural wisdom.
#  Hebrew		0.24420197308063507		Modern Hebrew has evolved by incorporating loanwords from various European languages.
#  Hebrew		0.24645327031612396		The renaissance of Hebrew was pivotal in shaping the cultural fabric of Israel.
#  Hebrew		0.24961009621620178		Many Hebrew expressions carry deep spiritual and historical significance.
#  Hebrew		0.2504902184009552		The revival of modern Hebrew in the 19th century stands as a remarkable linguistic achievement.
#  Hebrew		0.25160539150238037		Exploring Hebrew opens a window into a rich tapestry of religious and cultural narratives.
#  Hebrew		0.2550165057182312		The Hebrew alphabet, consisting of 22 letters, provides each with a unique sound.
# ###########3#############
#
#  Arabic		0.025199562311172485		The expansive vocabulary of Arabic allows speakers to articulate complex ideas poetically.
#  Arabic		0.025626007467508316		Diverse Arabic dialects add to the region's vibrant cultural mosaic.
#  Mandarin		0.02570866420865059		Many dialects exist in Chinese, with Mandarin and Cantonese being among the most recognized.
#  Arabic		0.026563115417957306		Classical Arabic texts have shaped philosophical and scientific thought over centuries.
#  Arabic		0.026604773476719856		Studying Arabic deepens one��s appreciation of art, history, and diverse cultural
#  Arabic		0.026885922998189926		Various Arabic dialects illustrate the diversity and cultural depth of the Middle East.
# Italian		0.026994677260518074		Italian literature spans from medieval epics to modern masterpieces.
# Italian		0.026994990184903145		Italian opera is celebrated around the world for its passion and drama.
# Italian		0.026995092630386353		Italian is known for its musicality and expressive, lyrical tone.
# Italian		0.026995303109288216		Italian poetry and prose continue to inspire creative expression worldwide.
# Italian		0.026995422318577766		Italian cuisine, famous globally, mirrors the diversity of dialects found in Italy.
#  Arabic		0.027388088405132294		Traditional Arabic proverbs are steeped in history and cultural wisdom.
# quez		0.031276267021894455		 is enriched by classics from Cervantes to Gabriel García Márquez.
#  La		0.032710086554288864		Festivals like La Tomatina showcase the lively and communal spirit of the Spanish language.
# ía		0.03490307554602623		Spanish literature is enriched by classics from Cervantes to Gabriel García Márquez.
#  Garc		0.03751596063375473		Spanish literature is enriched by classics from Cervantes to Gabriel García Márquez.
#  English		0.04373352602124214		Modern Japanese effortlessly incorporates loanwords from English and other languages.
# Latin		0.059149034321308136		Latin roots are deeply embedded in Italian, giving it a timeless quality.
#  Latin		0.06906137615442276		The language embodies a blend of European traditions and Latin American spirit.
#  Latin		0.07170190662145615		Learning Spanish offers a doorway to the diverse cultures of Latin America and Spain.
#  Spain		0.17160113155841827		Learning Spanish offers a doorway to the diverse cultures of Latin America and Spain.
# Spanish		0.20743627846240997		Spanish is one of the most widely spoken languages, connecting people across continents.
# Spanish		0.2074364423751831		Spanish cinema has left an indelible mark on global film and storytelling.
# Spanish		0.2074364870786667		Spanish is more than just a language—it is a vibrant window into rich histories
# Spanish		0.20743665099143982		Spanish literature is enriched by classics from Cervantes to Gabriel García Má
# Spanish		0.20743702352046967		Spanish is celebrated for its contributions to art, music, and global literature.
#  Spanish		0.21202002465724945		Festivals like La Tomatina showcase the lively and communal spirit of the Spanish language.
#  Spanish		0.2132684588432312		The lyrical pronunciation of Spanish adds beauty to its spoken word.
#  Spanish		0.21385636925697327		Globally, Spanish language courses attract learners with their cultural allure.
#  Spanish		0.21761101484298706		Regional variations in Spanish reflect the rich cultural diversity of its speakers.
#  Spanish		0.21881085634231567		The intricacies of Spanish grammar, with its gendered nouns and verb conjugations, present
#  Spanish		0.21881109476089478		The expressive tone of Spanish makes it a language full of passion and rhythm.
#  Spanish		0.21987099945545197		The natural cadence of Spanish often makes it a favorite language for music and poetry.
#  Spanish		0.22031576931476593		Over centuries, Spanish has evolved through a blend of regional dialects.
#  Spanish		0.22036314010620117		Common Spanish idioms encapsulate centuries of cultural experience.
#  Spanish		0.22197869420051575		Traditional Spanish proverbs offer timeless insights into life and culture.
#  Spanish		0.22253772616386414		Modern Spanish continually evolves with new slang and contemporary expressions.
#  Spanish		0.22316358983516693		Learning Spanish enhances travel experiences in many vibrant countries.
#  Spanish		0.22316372394561768		Learning Spanish offers a doorway to the diverse cultures of Latin America and Spain.
#  Spanish		0.22388014197349548		Many Spanish phrases have become part of everyday international vocabulary.
# ###########4#############
#
#  rhythm		0.03802945837378502		German poetry is known for its structured rhythm and emotional depth.
#  po		0.03832367807626724		The expansive vocabulary of Arabic allows speakers to articulate complex ideas poetically.
#  expressive		0.03869575262069702		The expressive tone of Spanish makes it a language full of passion and rhythm.
#  expressive		0.03869575634598732		The expressive intonation of Russian adds emotional depth to its spoken word.
#  Garc		0.040392857044935226		Spanish literature is enriched by classics from Cervantes to Gabriel García Márquez.
#  prose		0.04311458393931389		Italian poetry and prose continue to inspire creative expression worldwide.
#  rhythm		0.04360920190811157		The melodic rhythm of French makes it a popular language to learn and recite.
#  recite		0.04398074373602867		The melodic rhythm of French makes it a popular language to learn and recite.
#  Cyr		0.0443357490003109		The Cyrillic alphabet gives Russian its unique written character and visual appeal.
# igraph		0.04737846925854683		Hebrew calligraphy is an art that celebrates both form and cultural heritage.
# igraph		0.04797576367855072		Japanese calligraphy is both an art form and a means of powerful expression.
# igraph		0.0482516847550869		Traditional Chinese calligraphy is celebrated as an art form that blends technique and expression.
# igraph		0.04825543612241745		Chinese calligraphy emphasizes balance, beauty, and the rhythm of brush strokes.
# igraph		0.04986098036170006		Korean calligraphy is an artistic practice that highlights the beauty of the language.
# igraph		0.049865007400512695		The flowing, intricate Arabic script is admired for its artistic calligraphy.
# igraph		0.05320798233151436		Calligraphy in Arabic is not just writing—it is a celebrated form of art
#  emot		0.05783766880631447		Arabic music and poetry are celebrated worldwide for their emotive power and lyrical beauty.
# ical		0.06460237503051758		Arabic music and poetry are celebrated worldwide for their emotive power and lyrical beauty.
# ical		0.07101385295391083		The lyrical pronunciation of Spanish adds beauty to its spoken word.
# ical		0.07101407647132874		The lyrical pronunciation of Italian makes every conversation sound like music.
# ical		0.07482139021158218		Emotive Russian poetry is celebrated for its lyrical beauty and profound themes.
# ical		0.07522443681955338		Italian is known for its musicality and expressive, lyrical tone.
#  rhyth		0.10341320931911469		Hebrew poetry is noted for its rhythmic beauty and evocative imagery.
#  rhyth		0.11573551595211029		The rhythmic flow of Italian speech is as delightful as its culinary traditions.
#  lyr		0.20603244006633759		Italian is known for its musicality and expressive, lyrical tone.
#  lyr		0.21215535700321198		Arabic music and poetry are celebrated worldwide for their emotive power and lyrical beauty.
#  lyr		0.21499748528003693		Emotive Russian poetry is celebrated for its lyrical beauty and profound themes.
#  lyr		0.21815885603427887		The lyrical pronunciation of Spanish adds beauty to its spoken word.
#  lyr		0.21815887093544006		The lyrical pronunciation of Italian makes every conversation sound like music.
#  poetry		0.22433993220329285		Korean literature ranges from classical poetry to innovative modern novels.
#  poetry		0.22474366426467896		The natural cadence of Spanish often makes it a favorite language for music and poetry.
#  poetry		0.22507454454898834		Arabic literature boasts an impressive legacy of poetry, prose, and storytelling.
#  poetry		0.22861750423908234		Arabic music and poetry are celebrated worldwide for their emotive power and lyrical beauty.
#  poetry		0.22868376970291138		Classical Chinese poetry is admired for its brevity and profound imagery.
#  poetry		0.2312072217464447		Haiku, a classic form of Japanese poetry, captures the essence of nature in few words.
#  poetry		0.23807454109191895		German poetry is known for its structured rhythm and emotional depth.
#  poetry		0.23909756541252136		Hebrew poetry is noted for its rhythmic beauty and evocative imagery.
#  poetry		0.24237482249736786		Italian poetry and prose continue to inspire creative expression worldwide.
#  poetry		0.2427765280008316		Emotive Russian poetry is celebrated for its lyrical beauty and profound themes.
#  poetic		0.24643424153327942		Russian cinema frequently showcases the poetic and complex nature of its language.
# ###########5#############
#
# umerous		0.019303590059280396		Numerous ancient manuscripts and texts are written in the Hebrew language.
#  evident		0.020773688331246376		The impact of German on scientific and technical vocabulary is evident worldwide.
#  used		0.021078914403915405		Modern Standard Arabic is the formal language used in news, literature, and education.
#  also		0.021574893966317177		Learning French is not only about language but also about embracing a unique way of life.
#  intric		0.02254134975373745		The intricacies of Spanish grammar, with its gendered nouns and verb conjug
#  enduring		0.02277575246989727		Timeless French proverbs offer a glimpse into the nation's enduring wisdom.
#  variations		0.02318038046360016		Regional variations in Spanish reflect the rich cultural diversity of its speakers.
#  variations		0.02318038046360016		Regional variations in French highlight the diverse cultural landscape of France.
#  closely		0.023184040561318398		Italy��s rich art and architecture are closely tied to its expressive language.
#  closely		0.025339508429169655		Traditional storytelling in Japan is closely linked to the nuances of its language.
#  enduring		0.025646790862083435		Modern Chinese literature reflects both rapid societal changes and enduring traditions.
#  closely		0.025732288137078285		The spread of Arabic was closely linked to the expansion of the early Islamic empire.
#  closely		0.027192773297429085		Fashion and art in France are closely linked to the sophistication of its language.
#  popular		0.02886636182665825		The melodic rhythm of French makes it a popular language to learn and recite.
#  continuously		0.02960480935871601		Hebrew is one of the oldest continuously used languages in the world.
#  continuously		0.030718032270669937		New words and expressions continuously shape the modern Korean lexicon.
# Much		0.031115932390093803		Much like its cuisine, the Korean language is rich in flavor and diversity.
#  popular		0.032076865434646606		University courses in Chinese are increasingly popular as global interest grows.
#  particularly		0.036583561450242996		The melodious nature of Italian makes it particularly appealing to language enthusiasts.
#  eager		0.03959684446454048		Russian language courses attract those eager to explore Eastern European history.
# Common		0.04058629646897316		Common Spanish idioms encapsulate centuries of cultural experience.
# Common		0.04058633744716644		Common Italian idioms capture the warmth and charm of everyday life.
# Common		0.04058636724948883		Common Hebrew idioms encapsulate centuries of cultural wisdom.
#  seamlessly		0.04420390725135803		Modern Italian seamlessly blends traditional expressions with contemporary slang.
#  varied		0.044374506920576096		Regional dialects in German showcase the varied cultural heritage of its regions.
#  increasingly		0.06280729919672012		University courses in Chinese are increasingly popular as global interest grows.
#  effortlessly		0.07428374886512756		Modern Japanese effortlessly incorporates loanwords from English and other languages.
#  widely		0.08818933367729187		Spanish is one of the most widely spoken languages, connecting people across continents.
#  continually		0.09014543890953064		Modern Spanish continually evolves with new slang and contemporary expressions.
#  frequently		0.2265407145023346		Russian cinema frequently showcases the poetic and complex nature of its language.
#  often		0.28467804193496704		The natural cadence of Spanish often makes it a favorite language for music and poetry.
#  often		0.28490933775901794		Traditional idioms in Japanese often express cultural values and historical narratives.
#  often		0.28962063789367676		Traditional festivals in Japan often highlight the beauty of its language and customs.
#  often		0.2900907099246979		Festivals in Italy often celebrate the language through music, dance, and drama.
#  often		0.29132595658302307		Russian idioms and proverbs often reflect the resilience and spirit of its people.
#  often		0.29203107953071594		Festivals in China often highlight ancient customs and the beauty of the Chinese language.
#  often		0.29411938786506653		The Italian language is often associated with romance, art, and passion.
#  often		0.29430386424064636		Festivals in Germany often feature songs and traditions that celebrate the language.
#  often		0.295083612203598		Idiomatic expressions in Chinese, like 'Chengyu', often derive from historical tales.
#  often		0.29590991139411926		Festivals in Korea often celebrate both traditional heritage and the evolving language.
# ###########6#############
#
#  nuances		0.02316504344344139		Unique expressions in Korean capture the subtle cultural nuances of daily life.
# igraph		0.02351924404501915		Chinese calligraphy emphasizes balance, beauty, and the rhythm of brush strokes.
#  timeless		0.023604022338986397		Hebrew literature spans from timeless scriptures to modern novels.
#  vocabulary		0.024336805567145348		The impact of German on scientific and technical vocabulary is evident worldwide.
#  nuances		0.024976063519716263		Traditional storytelling in Japan is closely linked to the nuances of its language.
#  nuances		0.025960903614759445		Popular Korean films and dramas have introduced many to the nuances of the language.
#  vocabulary		0.026879584416747093		Many Spanish phrases have become part of everyday international vocabulary.
# igraph		0.02693602815270424		Calligraphy in Arabic is not just writing—it is a celebrated form of art
#  vocabulary		0.02734866924583912		The expansive vocabulary of Arabic allows speakers to articulate complex ideas poetically.
#  rhyth		0.02846478670835495		The rhythmic flow of Italian speech is as delightful as its culinary traditions.
#  Garc		0.031611986458301544		Spanish literature is enriched by classics from Cervantes to Gabriel García Márquez.
#  succinct		0.031791508197784424		Japanese literature spans from succinct haiku to expansive contemporary novels.
#  pronunciation		0.03223706781864166		The elegant pronunciation of French gives the language its unique charm.
#  intric		0.032587211579084396		Studying Japanese reveals the intricacies of an elegant and layered writing system.
#  pronunciation		0.03310991823673248		The lyrical pronunciation of Spanish adds beauty to its spoken word.
#  pronunciation		0.033110931515693665		The lyrical pronunciation of Italian makes every conversation sound like music.
#  concise		0.03996281325817108		Chinese proverbs are renowned for their wisdom and concise expressions of life lessons.
#  intric		0.040013350546360016		The intricacies of Spanish grammar, with its gendered nouns and verb conjug
#  logical		0.041524339467287064		The logical structure of the Korean language makes learning it a rewarding challenge.
#  phrases		0.051925137639045715		Many Spanish phrases have become part of everyday international vocabulary.
#  eleg		0.0526917465031147		Japanese is a language that elegantly fuses ancient traditions with modern technology.
#  noun		0.06142586097121239		The intricacies of Spanish grammar, with its gendered nouns and verb conjugations, present a delightful challenge.
#  noun		0.06313230842351913		German grammar, with its cases and gendered nouns, presents a fascinating linguistic structure.
#  idi		0.0643765851855278		Common Spanish idioms encapsulate centuries of cultural experience.
#  idi		0.06494778394699097		Common Italian idioms capture the warmth and charm of everyday life.
#  idi		0.0654234066605568		Common Hebrew idioms encapsulate centuries of cultural wisdom.
#  idi		0.06601757556200027		Traditional German idioms reflect the practical wisdom and humor of its speakers.
#  idi		0.06859105825424194		Many Chinese idioms are intertwined with natural imagery and philosophical insights.
#  idi		0.06878744810819626		Russian idioms and proverbs often reflect the resilience and spirit of its people.
#  idi		0.07002201676368713		Traditional idioms in Japanese often express cultural values and historical narratives.
#  idi		0.07205230742692947		French idioms capture subtle emotions and a nuanced cultural history.
#  verb		0.1690390259027481		The intricacies of Spanish grammar, with its gendered nouns and verb conjugations, present a delightful challenge.
# verbs		0.32234278321266174		Traditional Korean proverbs offer wisdom that has been passed down through generations.
# verbs		0.32262736558914185		Traditional Arabic proverbs are steeped in history and cultural wisdom.
# verbs		0.323894202709198		Russian idioms and proverbs often reflect the resilience and spirit of its people.
# verbs		0.3240301311016083		Traditional Russian proverbs offer a window into the values and hardships of its past.
# verbs		0.3241284489631653		Traditional Spanish proverbs offer timeless insights into life and culture.
# verbs		0.3244190514087677		Timeless French proverbs offer a glimpse into the nation's enduring wisdom.
# verbs		0.32646673917770386		Many Japanese proverbs convey deep cultural wisdom and life lessons.
# verbs		0.3298989534378052		Chinese proverbs are renowned for their wisdom and concise expressions of life lessons.
# ###########7#############
#
#  poetry		0.022616827860474586		Haiku, a classic form of Japanese poetry, captures the essence of nature in few words.
#  love		0.02374388836324215		French is celebrated as a language of love, art, and international diplomacy.
#  poetry		0.02502894401550293		Emotive Russian poetry is celebrated for its lyrical beauty and profound themes.
#  brush		0.025376537814736366		Chinese calligraphy emphasizes balance, beauty, and the rhythm of brush strokes.
#  poetry		0.025591565296053886		German poetry is known for its structured rhythm and emotional depth.
#  poetry		0.02736654132604599		Italian poetry and prose continue to inspire creative expression worldwide.
#  culinary		0.027565404772758484		 Italian language is a vital component of the nation's art, music, and culinary heritage.
#  poetry		0.029393544420599937		Hebrew poetry is noted for its rhythmic beauty and evocative imagery.
#  admired		0.029826346784830093		Classical Chinese poetry is admired for its brevity and profound imagery.
#  charm		0.0302059818059206		Common Italian idioms capture the warmth and charm of everyday life.
#  charm		0.031464796513319016		The elegant pronunciation of French gives the language its unique charm.
#  renaissance		0.03178142011165619		The renaissance of Hebrew was pivotal in shaping the cultural fabric of Israel.
#  culinary		0.03204524517059326		Learning French unveils a world of culinary delights and sophisticated expression.
#  culinary		0.03221726417541504		The rhythmic flow of Italian speech is as delightful as its culinary traditions.
#  simplicity		0.0331132747232914		Hangul is admired for its simplicity, phonetic design, and visual harmony.
#  admired		0.035437826067209244		Hangul is admired for its simplicity, phonetic design, and visual harmony.
#  admired		0.03594722971320152		The flowing, intricate Arabic script is admired for its artistic calligraphy.
#  artistic		0.036147937178611755		French cinema has long been recognized for its innovative storytelling and artistic flair.
#  style		0.037210192531347275		Japanese cinema has had a lasting impact on global film through its distinctive style.
#  artistic		0.039517756551504135		The Japanese language is at the heart of the country��s vibrant artistic heritage.
#  artistic		0.03955191746354103		The flowing, intricate Arabic script is admired for its artistic calligraphy.
#  quality		0.04182746633887291		Latin roots are deeply embedded in Italian, giving it a timeless quality.
#  delightful		0.04238472133874893		, with its gendered nouns and verb conjugations, present a delightful challenge.
#  artistic		0.0449889600276947		Korean calligraphy is an artistic practice that highlights the beauty of the language.
#  delightful		0.049382250756025314		The rhythmic flow of Italian speech is as delightful as its culinary traditions.
#  delightful		0.0514625683426857		Learning Italian is a delightful journey into the art and spirit of Italy.
# ashion		0.06601065397262573		Fashion and art in France are closely linked to the sophistication of its language.
#  elegant		0.07338115572929382		Written from right to left, the Hebrew script is both elegant and distinctive.
#  elegant		0.08278191834688187		Studying Japanese reveals the intricacies of an elegant and layered writing system.
#  elegant		0.08793118596076965		The elegant pronunciation of French gives the language its unique charm.
#  adorned		0.11057800054550171		French literature is adorned with masterpieces by writers like Voltaire and Hugo.
#  elegance		0.14405983686447144		The sound of Russian evokes both strength and an understated elegance.
#  beauty		0.3114071786403656		ic music and poetry are celebrated worldwide for their emotive power and lyrical beauty.
#  beauty		0.3152117431163788		Emotive Russian poetry is celebrated for its lyrical beauty and profound themes.
#  beauty		0.32418063282966614		Festivals in China often highlight ancient customs and the beauty of the Chinese language.
#  beauty		0.3262149393558502		Traditional festivals in Japan often highlight the beauty of its language and customs.
#  beauty		0.32673749327659607		The lyrical pronunciation of Spanish adds beauty to its spoken word.
#  beauty		0.32935965061187744		Hebrew poetry is noted for its rhythmic beauty and evocative imagery.
#  beauty		0.33174532651901245		Korean calligraphy is an artistic practice that highlights the beauty of the language.
#  beauty		0.33901092410087585		Chinese calligraphy emphasizes balance, beauty, and the rhythm of brush strokes.
# ###########8#############
#
#  historical		0.02582559548318386		iomatic expressions in Chinese, like 'Chengyu', often derive from historical tales.
#  expressive		0.025972742587327957		Italian is known for its musicality and expressive, lyrical tone.
#  expressive		0.026246296241879463		The expressive tone of Spanish makes it a language full of passion and rhythm.
#  expressive		0.02624629996716976		The expressive intonation of Russian adds emotional depth to its spoken word.
#  expansive		0.026649070903658867		Japanese literature spans from succinct haiku to expansive contemporary novels.
#  centuries		0.027264397591352463		The history of the Russian language spans centuries of cultural evolution.
#  advancements		0.02783510647714138		Technological advancements continue to shape modern Chinese slang and expressions.
#  century		0.027963848784565926		The revival of modern Hebrew in the 19th century stands as a remarkable linguistic achievement.
#  historical		0.028414301574230194		Studying Korean provides deep insights into historical traditions and modern innovations.
#  expansive		0.028796060010790825		The expansive vocabulary of Arabic allows speakers to articulate complex ideas poetically.
#  centuries		0.029035964980721474		Classical Arabic texts have shaped philosophical and scientific thought over centuries.
#  renaissance		0.029483338817954063		The renaissance of Hebrew was pivotal in shaping the cultural fabric of Israel.
#  centuries		0.030039606615900993		Studying French deepens your appreciation for centuries of European culture.
#  centuries		0.030533745884895325		Common Spanish idioms encapsulate centuries of cultural experience.
#  modern		0.032403744757175446		Contemporary Korean media presents a vibrant mix of age-old traditions and modern trends.
#  centuries		0.033152613788843155		Common Hebrew idioms encapsulate centuries of cultural wisdom.
#  rhyth		0.03352775424718857		Hebrew poetry is noted for its rhythmic beauty and evocative imagery.
#  historical		0.03399856388568878		Many Hebrew expressions carry deep spiritual and historical significance.
#  modern		0.03441339358687401		Contemporary Arabic media reflects a blend of tradition and modern storytelling.
#  centuries		0.03533679619431496		Over centuries, Spanish has evolved through a blend of regional dialects.
#  historical		0.035416655242443085		Traditional idioms in Japanese often express cultural values and historical narratives.
#  generations		0.04086020961403847		Traditional Korean proverbs offer wisdom that has been passed down through generations.
#  rhyth		0.0423128679394722		The rhythmic flow of Italian speech is as delightful as its culinary traditions.
#  societal		0.04247286170721054		Modern Chinese literature reflects both rapid societal changes and enduring traditions.
# umerous		0.04559285566210747		Numerous ancient manuscripts and texts are written in the Hebrew language.
#  timeless		0.04823293909430504		Latin roots are deeply embedded in Italian, giving it a timeless quality.
#  classical		0.049180787056684494		Modern Russian media reflects a fusion of classical storytelling with contemporary news.
#  timeless		0.05178872495889664		Hebrew literature spans from timeless scriptures to modern novels.
#  timeless		0.051965177059173584		Traditional Spanish proverbs offer timeless insights into life and culture.
#  classical		0.05448297783732414		Modern German skillfully blends classical expressions with new, innovative slang.
#  classical		0.05458013340830803		Korean literature ranges from classical poetry to innovative modern novels.
#  contemporary		0.30719462037086487		Japanese literature spans from succinct haiku to expansive contemporary novels.
#  contemporary		0.30877095460891724		Modern Russian media reflects a fusion of classical storytelling with contemporary news.
# emporary		0.3102140724658966		Contemporary Korean media presents a vibrant mix of age-old traditions and modern trends.
# emporary		0.3102171719074249		Contemporary Arabic media reflects a blend of tradition and modern storytelling.
#  contemporary		0.311832457780838		Modern Spanish continually evolves with new slang and contemporary expressions.
#  contemporary		0.3136294186115265		Language classes in Hebrew attract those fascinated by both history and contemporary culture.
#  contemporary		0.31530267000198364		Modern Korean artfully blends traditional expressions with contemporary slang.
#  contemporary		0.3156806528568268		Modern Italian seamlessly blends traditional expressions with contemporary slang.
#  contemporary		0.3166652321815491		Modern French incorporates both traditional expressions and fresh, contemporary ideas.
# ###########9#############
#
#  renaissance		0.012088239192962646		The renaissance of Hebrew was pivotal in shaping the cultural fabric of Israel.
#  medieval		0.012203001417219639		Italian literature spans from medieval epics to modern masterpieces.
#  classical		0.012502782046794891		Korean literature ranges from classical poetry to innovative modern novels.
#  mosaic		0.013010731898248196		Diverse Arabic dialects add to the region's vibrant cultural mosaic.
#  classical		0.01385532971471548		Modern German skillfully blends classical expressions with new, innovative slang.
#  Latin		0.01385999470949173		Learning Spanish offers a doorway to the diverse cultures of Latin America and Spain.
# Latin		0.013936170376837254		Latin roots are deeply embedded in Italian, giving it a timeless quality.
#  cuisine		0.015053612180054188		Italian cuisine, famous globally, mirrors the diversity of dialects found in Italy.
#  Latin		0.015057584270834923		The language embodies a blend of European traditions and Latin American spirit.
#  eleg		0.023748578503727913		Japanese is a language that elegantly fuses ancient traditions with modern technology.
#  elegance		0.024984203279018402		The sound of Russian evokes both strength and an understated elegance.
#  elegant		0.02795400470495224		Written from right to left, the Hebrew script is both elegant and distinctive.
#  elegant		0.02858487144112587		Studying Japanese reveals the intricacies of an elegant and layered writing system.
#  elegant		0.028965970501303673		The elegant pronunciation of French gives the language its unique charm.
#  opera		0.029202090576291084		Chinese opera combines music, drama, and language into a vibrant cultural spectacle.
#  opera		0.03462661802768707		Italian opera is celebrated around the world for its passion and drama.
#  classics		0.03651138022542		Spanish literature is enriched by classics from Cervantes to Gabriel García Márquez.
#  Mediterranean		0.07870432734489441		Studying Italian opens a window into the heart of Mediterranean culture.
#  Italy		0.1748177409172058		Learning Italian is a delightful journey into the art and spirit of Italy.
#  Italy		0.17568157613277435		Italian cuisine, famous globally, mirrors the diversity of dialects found in Italy.
#  Italy		0.17624936997890472		Festivals in Italy often celebrate the language through music, dance, and drama.
# Italy		0.17914550006389618		Italy��s rich art and architecture are closely tied to its expressive language.
# Italian		0.2051534205675125		Italian literature spans from medieval epics to modern masterpieces.
# Italian		0.2051534503698349		Italian cuisine, famous globally, mirrors the diversity of dialects found in Italy.
# Italian		0.2051534801721573		Italian is known for its musicality and expressive, lyrical tone.
# Italian		0.20515356957912445		Italian poetry and prose continue to inspire creative expression worldwide.
# Italian		0.20515404641628265		Italian opera is celebrated around the world for its passion and drama.
#  Italian		0.2086568921804428		Latin roots are deeply embedded in Italian, giving it a timeless quality.
#  Italian		0.21108825504779816		The lyrical pronunciation of Italian makes every conversation sound like music.
#  Italian		0.21227049827575684		The melodious nature of Italian makes it particularly appealing to language enthusiasts.
#  Italian		0.2148113250732422		The rhythmic flow of Italian speech is as delightful as its culinary traditions.
#  Italian		0.21723595261573792		The evolution of Italian has been influenced by numerous regional dialects over time.
#  Italian		0.21825551986694336		Common Italian idioms capture the warmth and charm of everyday life.
#  Italian		0.2185606062412262		Studying Italian opens a window into the heart of Mediterranean culture.
#  Italian		0.2185656577348709		Modern Italian seamlessly blends traditional expressions with contemporary slang.
#  Italian		0.22105397284030914		Learning Italian is a delightful journey into the art and spirit of Italy.
#  Italian		0.2210540473461151		Learning Italian provides a glimpse into a culture steeped in history and creativity.
#  Italian		0.22133253514766693		The Italian language is a vital component of the nation's art, music, and culinary
#  Italian		0.22133265435695648		The Italian language is often associated with romance, art, and passion.
#  Italian		0.22159886360168457		Many Italian expressions capture the soul and history of the country.
# ###########10#############
#
# vity		0.02736712619662285		Classical Chinese poetry is admired for its brevity and profound imagery.
#  emotions		0.02805252932012081		French idioms capture subtle emotions and a nuanced cultural history.
#  beauty		0.029046645388007164		Emotive Russian poetry is celebrated for its lyrical beauty and profound themes.
#  beauty		0.030049020424485207		Festivals in China often highlight ancient customs and the beauty of the Chinese language.
#  beauty		0.031430069357156754		The lyrical pronunciation of Spanish adds beauty to its spoken word.
#  spectacle		0.031546078622341156		Chinese opera combines music, drama, and language into a vibrant cultural spectacle.
#  beauty		0.0329289548099041		Chinese calligraphy emphasizes balance, beauty, and the rhythm of brush strokes.
#  beauty		0.03296184167265892		Traditional festivals in Japan often highlight the beauty of its language and customs.
#  beauty		0.03593016788363457		Korean calligraphy is an artistic practice that highlights the beauty of the language.
#  beauty		0.036323245614767075		Hebrew poetry is noted for its rhythmic beauty and evocative imagery.
#  wisdom		0.03785450756549835		Timeless French proverbs offer a glimpse into the nation's enduring wisdom.
#  wisdom		0.03881992772221565		Traditional Arabic proverbs are steeped in history and cultural wisdom.
#  wisdom		0.038988325744867325		Many Japanese proverbs convey deep cultural wisdom and life lessons.
#  wisdom		0.0401274710893631		Chinese proverbs are renowned for their wisdom and concise expressions of life lessons.
#  wisdom		0.040769267827272415		Traditional German idioms reflect the practical wisdom and humor of its speakers.
#  wisdom		0.041871100664138794		Common Hebrew idioms encapsulate centuries of cultural wisdom.
#  wisdom		0.04287957772612572		Traditional Korean proverbs offer wisdom that has been passed down through generations.
#  harmony		0.04455159977078438		Hangul is admired for its simplicity, phonetic design, and visual harmony.
#  society		0.04709375277161598		The evolution of Korean mirrors the dynamic changes occurring in modern society.
#  life		0.05002168193459511		Learning French is not only about language but also about embracing a unique way of life.
#  life		0.050252772867679596		Chinese proverbs are renowned for their wisdom and concise expressions of life lessons.
#  life		0.050294168293476105		Traditional Spanish proverbs offer timeless insights into life and culture.
#  life		0.050899919122457504		Common Italian idioms capture the warmth and charm of everyday life.
#  life		0.05272606015205383		Unique expressions in Korean capture the subtle cultural nuances of daily life.
#  simplicity		0.05383340269327164		Hangul is admired for its simplicity, phonetic design, and visual harmony.
#  life		0.05459768697619438		Many Japanese proverbs convey deep cultural wisdom and life lessons.
#  spirit		0.0697103962302208		Learning Italian is a delightful journey into the art and spirit of Italy.
#  spirit		0.07153739780187607		The language embodies a blend of European traditions and Latin American spirit.
# ...
# igraph		0.05623909458518028		Calligraphy in Arabic is not just writing—it is a celebrated form of art
#  Slav		0.060960378497838974		Russian is a Slavic language known for its deep literary and cultural heritage.
#  phon		0.06745444983243942		Hangul is admired for its simplicity, phonetic design, and visual harmony.
#  slang		0.06939039379358292		Modern Korean artfully blends traditional expressions with contemporary slang.
#  slang		0.07229560613632202		Modern Italian seamlessly blends traditional expressions with contemporary slang.
#  slang		0.07430997490882874		Technological advancements continue to shape modern Chinese slang and expressions.
#  slang		0.07453588396310806		Modern German skillfully blends classical expressions with new, innovative slang.
#  rhyth		0.07475040853023529		Hebrew poetry is noted for its rhythmic beauty and evocative imagery.
#  slang		0.07478730380535126		Modern Spanish continually evolves with new slang and contemporary expressions.
#  slang		0.07549311220645905		Modern Russian successfully blends time-honored expressions with evolving slang.
#  rhyth		0.08607462048530579		The rhythmic flow of Italian speech is as delightful as its culinary traditions.
#  dialect		0.31679800152778625		Over centuries, Spanish has evolved through a blend of regional dialects.
#  dialect		0.3178803622722626		Various Arabic dialects illustrate the diversity and cultural depth of the Middle East.
#  dialect		0.31824663281440735		Regional dialects in German showcase the varied cultural heritage of its regions.
#  dialect		0.32116463780403137		Diverse Arabic dialects add to the region's vibrant cultural mosaic.
#  dialect		0.3222043216228485		Italian cuisine, famous globally, mirrors the diversity of dialects found in Italy.
#  dialect		0.3234432339668274		Diverse regional dialects in Russian mirror the vast geography of the nation.
#  dialect		0.325207382440567		The evolution of Italian has been influenced by numerous regional dialects over time.
#  dialect		0.32526567578315735		Many dialects exist in Chinese, with Mandarin and Cantonese being among the most
# ###########47#############
#
#  French		0.039983902126550674		The French language plays a key role in international organizations and diplomatic circles.
#  France		0.040261831134557724		Fashion and art in France are closely linked to the sophistication of its language.
#  Italian		0.04081197828054428		The Italian language is a vital component of the nation's art, music, and culinary
#  Italian		0.04081223905086517		The Italian language is often associated with romance, art, and passion.
#  Italian		0.041294246912002563		Learning Italian is a delightful journey into the art and spirit of Italy.
#  Italian		0.04129445180296898		Learning Italian provides a glimpse into a culture steeped in history and creativity.
#  Italian		0.041480712592601776		Many Italian expressions capture the soul and history of the country.
#  Italy		0.041573408991098404		Learning Italian is a delightful journey into the art and spirit of Italy.
#  Slav		0.04158353805541992		Russian is a Slavic language known for its deep literary and cultural heritage.
#  Latin		0.04159453138709068		The language embodies a blend of European traditions and Latin American spirit.
# French		0.0424443818628788		French literature is adorned with masterpieces by writers like Voltaire and Hugo.
# French		0.04244450107216835		French cinema has long been recognized for its innovative storytelling and artistic flair.
# French		0.042444512248039246		French cuisine, celebrated globally, is a testament to its cultural heritage.
# French		0.042444609105587006		French is celebrated as a language of love, art, and international diplomacy.
# French		0.04244465008378029		French idioms capture subtle emotions and a nuanced cultural history.
#  Italian		0.04254377633333206		Latin roots are deeply embedded in Italian, giving it a timeless quality.
#  Italian		0.043002236634492874		Modern Italian seamlessly blends traditional expressions with contemporary slang.
#  German		0.043401215225458145		Studying German provides deeper insights into European history and cultural thought.
#  French		0.045570649206638336		Studying French deepens your appreciation for centuries of European culture.
# Latin		0.04559086263179779		Latin roots are deeply embedded in Italian, giving it a timeless quality.
#  Italian		0.046340618282556534		Common Italian idioms capture the warmth and charm of everyday life.
#  Italy		0.046750757843256		Festivals in Italy often celebrate the language through music, dance, and drama.
#  Italian		0.04918992146849632		Studying Italian opens a window into the heart of Mediterranean culture.
# Italy		0.049303989857435226		Italy��s rich art and architecture are closely tied to its expressive language.
#  Eastern		0.06347084045410156		Russian language courses attract those eager to explore Eastern European history.
#  international		0.07593867182731628		French is celebrated as a language of love, art, and international diplomacy.
#  international		0.0761077031493187		Arabic remains essential in international dialogue, literature, and diplomatic relations.
#  international		0.07680362462997437		Many Spanish phrases have become part of everyday international vocabulary.
#  international		0.07753308862447739		Language schools around the world offer courses in Japanese, reflecting its international allure.
#  international		0.07930707186460495		The French language plays a key role in international organizations and diplomatic circles.
#  American		0.09051530063152313		The language embodies a blend of European traditions and Latin American spirit.
#  Western		0.09759847819805145		The structural differences between Chinese and Western languages make learning it an adventure.
#  continents		0.11090784519910812		Arabic is a language with a rich history and a deep cultural impact across continents.
#  continents		0.11585330963134766		Spanish is one of the most widely spoken languages, connecting people across continents.
#  Mediterranean		0.12562242150306702		Studying Italian opens a window into the heart of Mediterranean culture.
#  European		0.3706839084625244		Studying French deepens your appreciation for centuries of European culture.
#  European		0.3830994665622711		Modern Hebrew has evolved by incorporating loanwords from various European languages.
#  European		0.3894275724887848		Russian language courses attract those eager to explore Eastern European history.
#  European		0.3982974886894226		Studying German provides deeper insights into European history and cultural thought.
#  European		0.40598857402801514		The language embodies a blend of European traditions and Latin American spirit.
# ###########48#############
#
#  tradition		0.026814009994268417		Contemporary Arabic media reflects a blend of tradition and modern storytelling.
#  traditions		0.027078868821263313		 more than just a language—it is a vibrant window into rich histories and traditions.
#  generations		0.02854965254664421		Traditional Korean proverbs offer wisdom that has been passed down through generations.
#  legacy		0.028627969324588776		Arabic literature boasts an impressive legacy of poetry, prose, and storytelling.
#  centuries		0.02884281612932682		Over centuries, Spanish has evolved through a blend of regional dialects.
#  legacy		0.030029624700546265		Studying Korean offers a glimpse into a culture with a profound historical legacy.
#  traditions		0.03187726065516472		Studying Korean provides deep insights into historical traditions and modern innovations.
#  centuries		0.031984325498342514		Studying French deepens your appreciation for centuries of European culture.
#  past		0.032055024057626724		Learning Russian can be an enriching journey through a storied past and vibrant present.
#  centuries		0.03219166398048401		The history of the Russian language spans centuries of cultural evolution.
# oried		0.03223360329866409		Learning German is both challenging and rewarding, providing insight into a storied cultural legacy.
# oried		0.03309691697359085		Learning Russian can be an enriching journey through a storied past and vibrant present.
# oried		0.0358678437769413		Studying Russian unlocks insights into a complex and storied cultural history.
#  geography		0.055185914039611816		Diverse regional dialects in Russian mirror the vast geography of the nation.
#  historical		0.11767468601465225		Traditional idioms in Japanese often express cultural values and historical narratives.
#  historical		0.11974573880434036		Many Hebrew expressions carry deep spiritual and historical significance.
#  historical		0.1207815557718277		iomatic expressions in Chinese, like 'Chengyu', often derive from historical tales.
#  historical		0.12295001745223999		Studying Korean offers a glimpse into a culture with a profound historical legacy.
#  historical		0.12404613196849823		Studying Russian allows one to delve into rich historical narratives and cultural identity.
#  historical		0.12420067191123962		The evolution of French reflects the country��s dynamic historical changes.
#  historical		0.12610632181167603		Studying Chinese opens doors to a rich cultural heritage and historical depth.
#  historical		0.12660184502601624		Studying Korean provides deep insights into historical traditions and modern innovations.
#  histories		0.16306079924106598		Spanish is more than just a language—it is a vibrant window into rich histories and traditions.
#  history		0.1992563009262085		Ancient Hebrew inscriptions discovered at archaeological sites reveal rich history.
#  history		0.2047642022371292		The evolution of the German language mirrors the rich cultural history of the nation.
#  history		0.20537666976451874		Learning Japanese provides insight into a culture rich in history and innovation.
#  history		0.20699462294578552		Exploring the German language offers a window into a culture rich in history and innovation.
#  history		0.21021275222301483		Learning Arabic provides a gateway to understanding Islamic history and traditions.
#  history		0.2111458033323288		Learning Italian provides a glimpse into a culture steeped in history and creativity.
#  history		0.2112225741147995		French idioms capture subtle emotions and a nuanced cultural history.
#  history		0.21322035789489746		Russian language courses attract those eager to explore Eastern European history.
#  history		0.21758824586868286		Studying Arabic deepens one��s appreciation of art, history, and diverse cultural practices.
#  history		0.21799322962760925		Language classes in Hebrew attract those fascinated by both history and contemporary culture.
#  history		0.21812191605567932		Traditional Arabic proverbs are steeped in history and cultural wisdom.
#  history		0.21892310678958893		Many Italian expressions capture the soul and history of the country.
#  history		0.21958284080028534		Arabic is a language with a rich history and a deep cultural impact across continents.
#  history		0.22027461230754852		The German language has a long history of philosophical, literary, and scientific contributions.
#  history		0.22163629531860352		Studying Russian unlocks insights into a complex and storied cultural history.
#  history		0.22182929515838623		The history of the Russian language spans centuries of cultural evolution.
#  history		0.22236379981040955		Studying German provides deeper insights into European history and cultural thought.
# ###########49#############
#
#  hierarchy		0.023041091859340668		Korean grammar features honorifics and specific sentence structures that reflect social hierarchy.
#  feature		0.02331911399960518		Festivals in Germany often feature songs and traditions that celebrate the language.
#  fabric		0.023375725373625755		The renaissance of Hebrew was pivotal in shaping the cultural fabric of Israel.
#  expression		0.024518633261322975		Learning Japanese opens a door to a world of refined expression and cultural depth.
#  expression		0.02458186075091362		Renowned for its precise grammar, French is a language of refined expression.
#  boundaries		0.024770040065050125		Modern German literature continues to push creative boundaries and innovate.
#  conj		0.025121979415416718		The intricacies of Spanish grammar, with its gendered nouns and verb conjugations, present a delightful challenge.
#  landscape		0.025136716663837433		Regional variations in French highlight the diverse cultural landscape of France.
#  design		0.025858407840132713		Hangul is admired for its simplicity, phonetic design, and visual harmony.
#  expression		0.02681000903248787		Italian poetry and prose continue to inspire creative expression worldwide.
#  features		0.027160370722413063		The Japanese writing system features a unique mix of kanji, hiragana, and kat
#  decl		0.027379268780350685		The complex grammar of Russian—with its cases and declensions—offers an intriguing challenge.
#  technique		0.02856721170246601		Traditional Chinese calligraphy is celebrated as an art form that blends technique and expression.
#  features		0.03289556875824928		Korean grammar features honorifics and specific sentence structures that reflect social hierarchy.
#  essence		0.03301689773797989		Haiku, a classic form of Japanese poetry, captures the essence of nature in few words.
#  encaps		0.036922626197338104		Common Hebrew idioms encapsulate centuries of cultural wisdom.
#  exist		0.038065869361162186		Many dialects exist in Chinese, with Mandarin and Cantonese being among the most recognized.
#  encaps		0.03840068355202675		Common Spanish idioms encapsulate centuries of cultural experience.
#  style		0.03897593915462494		Japanese cinema has had a lasting impact on global film through its distinctive style.
#  component		0.044886622577905655		The Italian language is a vital component of the nation's art, music, and culinary heritage.
#  consisting		0.06145809590816498		The Hebrew alphabet, consisting of 22 letters, provides each with a unique sound.
#  formal		0.065031036734581		Modern Standard Arabic is the formal language used in news, literature, and education.
#  shaping		0.07200031727552414		The renaissance of Hebrew was pivotal in shaping the cultural fabric of Israel.
#  structured		0.09879904240369797		German poetry is known for its structured rhythm and emotional depth.
#  structural		0.10430557280778885		The structural differences between Chinese and Western languages make learning it an adventure.
#  shaped		0.10466251522302628		Classical Arabic texts have shaped philosophical and scientific thought over centuries.
#  structures		0.10932379961013794		Korean grammar features honorifics and specific sentence structures that reflect social hierarchy.
#  structured		0.11323174089193344		Clear and structured, German emphasizes precision in both speech and writing.
#  structure		0.13311028480529785		 grammar, with its cases and gendered nouns, presents a fascinating linguistic structure.
#  structure		0.16075296700000763		The logical structure of the Korean language makes learning it a rewarding challenge.
#  structure		0.16431421041488647		The structure of Japanese grammar presents unique challenges and rewards for learners.
#  formation		0.17535428702831268		The formation of compound words in German reveals the language��s analytical nature.
#  shape		0.18838472664356232		Technological advancements continue to shape modern Chinese slang and expressions.
#  shape		0.1951759308576584		New words and expressions continuously shape the modern Korean lexicon.
#  forms		0.3082095682621002		German is renowned for its precision and the unique way it forms compound words.
#  form		0.318571537733078		Japanese calligraphy is both an art form and a means of powerful expression.
#  form		0.3190860152244568		Calligraphy in Arabic is not just writing—it is a celebrated form of art.
#  form		0.3215765655040741		Traditional Chinese calligraphy is celebrated as an art form that blends technique and expression.
#  form		0.3337112069129944		Hebrew calligraphy is an art that celebrates both form and cultural heritage.
#  form		0.3709155321121216		Haiku, a classic form of Japanese poetry, captures the essence of nature in few words.

# %% [markdown]
# ### Interpreting Through Intervention

# %%
from intervention.intervener import Intervener

intervener = Intervener(act_generator.model)

# %% [markdown]
# #### Token Change (shows tokens whose logits changed the most due to intervention)

# %%
base_prompt = "I think that"

# %%
with torch.no_grad():
    base_logits = act_generator.model(act_generator.model.to_tokens(base_prompt))

# %%
alpha = 20
intervention_layer = 0

for i in range(50):
    
    print(f"#####################################{i}###########################")
    intervened_logits = intervener.intervene(
                    base_prompt,
                    [nmf.F_.T[i].to(device)], 
                    layers=[intervention_layer], 
                    alpha=alpha, 

    )
    print_logit_diff(intervener._model, base_logits, intervened_logits)
# Out:
# #####################################0###########################
# Top 10 ↑ logit changes:
#      available   +6.1005
#          gonna   +5.9424
#          ready   +5.8511
#             nt   +5.7252
#       destined   +5.7048
#    Constructed   +5.4889
#           ngth   +5.3702
#        capable   +5.3631
#      extremely   +5.3275
#           able   +5.3108
#
# Top 10 ↓ logit changes:
#             's   -6.9691
#    characterization   -5.2778
#      qualifies   -5.1798
#        settles   -5.1709
#      describes   -5.1527
#            was   -5.1405
#             if   -5.1085
#    description   -4.9497
#         Alexis   -4.8858
#         phrase   -4.8764
# #####################################1###########################
# Top 10 ↑ logit changes:
#        english   +2.9746
#            Dud   +2.8040
#      adjective   +2.5519
#            ain   +2.5270
#       sentence   +2.5157
#           verb   +2.4364
#           agre   +2.3902
#           ital   +2.3373
#             he   +2.3200
#         desper   +2.2126
#
# Top 10 ↓ logit changes:
#    cryptocurrencies   -2.6679
#    Photography   -2.4478
#    photography   -2.4071
#     ultimately   -2.3966
#         amidst   -2.3510
#     legalizing   -2.3326
#      photograp   -2.3125
#      embracing   -2.2276
#           LEGO   -2.2221
#      fostering   -2.1984
# #####################################2###########################
# Top 10 ↑ logit changes:
#              �   +10.2236
#    Translation   +9.8765
#         Arabic   +9.5948
#        Spanish   +9.4729
#          Notes   +9.4684
#          Gujar   +9.3142
#              �   +9.0562
#        Lithuan   +8.7739
#         Hebrew   +8.7549
#              �   +8.7014
#
# Top 10 ↓ logit changes:
#      everybody   -8.9734
#       everyone   -8.3687
#        anybody   -8.2715
#        Satoshi   -7.6261
#        whoever   -7.5762
#     forgetting   -7.4304
#         Ramsey   -7.4172
#         anyone   -7.2755
#        despite   -7.2126
#           Robb   -7.1113
# #####################################3###########################
# Top 10 ↑ logit changes:
#    ----------------   +10.3770
#    Description   +10.0766
#         Portug   +10.0494
#     Portuguese   +9.9348
#     Vietnamese   +9.5943
#    --------------------   +9.5760
#     Additional   +9.4068
#    Translation   +9.1395
#         French   +9.0244
#          Notes   +8.9047
#
# Top 10 ↓ logit changes:
#    libertarians   -9.2776
#        cloning   -8.3529
#      logically   -8.1571
#     legalizing   -7.9119
#        insofar   -7.8228
#       leftists   -7.6176
#      splitting   -7.4254
#       liberals   -7.3255
#         anyone   -7.3201
#       everyone   -7.2880
# #####################################4###########################
# Top 10 ↑ logit changes:
#          aloud   +7.8780
#          poems   +7.5897
#          cause   +6.9501
#         lyrics   +6.9461
#        Because   +6.8879
#        stories   +6.6945
#         verses   +6.6774
#           like   +6.6720
#             bc   +6.5870
#           Like   +6.5728
#
# Top 10 ↓ logit changes:
#                 -6.7864
#                 -6.7481
#                 -6.7459
#                 -6.7313
#                 -6.7049
#              �   -6.6841
#              �   -6.6734
#    externalToEVA   -6.6585
#             龍�   -6.6524
#                 -6.6480
# #####################################5###########################
# Top 10 ↑ logit changes:
#        entimes   +8.7655
#          Often   +8.3884
#       Referred   +8.3030
#          Often   +7.8934
#          Never   +7.7902
#          times   +7.6244
#         Always   +7.5824
#           Used   +7.5615
#           Used   +7.3619
#       Uncommon   +7.0760
#
# Top 10 ↓ logit changes:
#     legalizing   -7.7569
#       everyone   -6.3226
#             's   -6.2992
#        analogy   -6.2042
#    legalization   -6.0603
#          Tesla   -6.0473
#         Django   -6.0213
#      capturing   -6.0162
#      everybody   -5.8367
#            CCP   -5.7425
# #####################################6###########################
# Top 10 ↑ logit changes:
#         phrase   +2.1580
#          might   +2.1076
#            ain   +2.0866
#       sentence   +2.0489
#          ought   +2.0248
#        sounded   +1.9644
#         sounds   +1.9408
#     descriptor   +1.9032
#            may   +1.8512
#      adjective   +1.8342
#
# Top 10 ↓ logit changes:
#        Cookies   -1.9093
#    entrepreneurship   -1.8842
#    cryptocurrencies   -1.8403
#    breastfeeding   -1.7917
#        modular   -1.7587
#           Pets   -1.6918
#    photography   -1.6872
#    Photography   -1.6700
#         Eating   -1.6595
#      interoper   -1.6504
# #####################################7###########################
# Top 10 ↑ logit changes:
#          beaut   +9.3765
#          Beaut   +8.9175
#        pageant   +8.2709
#           ngth   +7.8975
#         beauty   +7.5253
#          beaut   +7.2110
#          salon   +6.9101
#          istry   +6.6155
#     complexion   +6.5464
#       Products   +6.4854
#
# Top 10 ↓ logit changes:
#        Satoshi   -8.2160
#          Ender   -7.8688
#        Randall   -6.8584
#      Greenwald   -6.8324
#        Tolkien   -6.6866
#            GHC   -6.6786
#           Elon   -6.6420
#           Schr   -6.5721
#           Alan   -6.4943
#          Ethan   -6.4827
# #####################################8###########################
# Top 10 ↑ logit changes:
#         cinema   +7.1272
#    architecture   +7.1078
#        cuisine   +6.9330
#        fashion   +6.8664
#     filmmaking   +6.7807
#           chic   +6.7108
#     lifestyles   +6.6927
#            art   +6.6787
#     literature   +6.6606
#      paintings   +6.6543
#
# Top 10 ↓ logit changes:
#      comparing   -5.7691
#     Stephenson   -5.7471
#          there   -5.5893
#        whoever   -5.5492
#           SOME   -5.4899
#           this   -5.4745
#       everyone   -5.4257
#        Cortana   -5.4237
#       removing   -5.3801
#      everybody   -5.3511
# #####################################9###########################
# Top 10 ↑ logit changes:
#        Italian   +9.0434
#        Italian   +8.8161
#        Spanish   +8.2364
#        Spanish   +8.0661
#           Ital   +7.9762
#     Portuguese   +7.8273
#              ⓘ   +7.5981
#            ese   +7.5929
#      Argentine   +7.5796
#     Additional   +7.5728
#
# Top 10 ↓ logit changes:
#         anyone   -8.0012
#       everyone   -7.8362
#        someday   -7.8086
#          there   -7.7358
#        anybody   -7.6969
#             we   -7.5591
#    introducing   -7.3528
#     legalizing   -7.1482
#       exposing   -6.9932
#        someone   -6.9694
# #####################################10###########################
# Top 10 ↑ logit changes:
#         nature   +9.5020
#         Nature   +8.6290
#         nature   +7.9588
#         Nature   +7.9477
#             の�   +7.6442
#           ngth   +7.3097
#             "}   +7.2864
#            NOW   +7.1839
#            ://   +7.1532
#         sonian   +7.0733
#
# Top 10 ↓ logit changes:
#         Django   -7.5298
#       everyone   -7.2959
#          Ender   -7.0817
#           Zack   -6.4872
#      everybody   -6.4362
#     legalizing   -6.2486
#            Zer   -6.2104
#          Valve   -6.1473
#          Gavin   -6.0949
#           Amir   -6.0023
# #####################################11###########################
# Top 10 ↑ logit changes:
#           brew   +13.0791
#         estate   +12.6240
#           hops   +12.0325
#            ery   +11.8900
#        details   +11.8821
#           ":{"   +11.7069
#           shop   +11.4333
#           city   +11.1931
#           beer   +11.1862
#            ing   +11.1483
#
# Top 10 ↓ logit changes:
#        Chomsky   -8.4572
#           most   -8.1695
#      Nietzsche   -8.0566
#         Turing   -8.0561
#       everyone   -7.8525
#        perhaps   -7.8224
#         Gandhi   -7.7746
#        neither   -7.7610
#           many   -7.7503
#         Ridley   -7.6920
# #####################################12###########################
# Top 10 ↑ logit changes:
#        Russian   +8.4861
#        Russian   +8.0460
#         Kazakh   +7.4788
#       Georgian   +7.2811
#           kaya   +7.2101
#              ы   +7.1880
#              �   +7.0642
#           ovan   +7.0179
#     Federation   +6.9580
#         Latest   +6.7097
#
# Top 10 ↓ logit changes:
#       everyone   -7.9121
#         anyone   -7.4504
#      comparing   -7.1779
#          there   -7.1734
#     legalizing   -7.1126
#             if   -6.7099
#             we   -6.6989
#        someone   -6.6408
#        someday   -6.6233
#           once   -6.5159
# #####################################13###########################
# Top 10 ↑ logit changes:
#           NEWS   +9.2735
#              �   +8.4762
#      Peninsula   +7.9959
#              �   +7.9090
#            ESE   +7.7040
#            Pak   +7.7021
#         EVENTS   +7.3312
#          orean   +7.2949
#         Korean   +7.2637
#   Interstitial   +7.1660
#
# Top 10 ↓ logit changes:
#        whoever   -8.7869
#       everyone   -8.5554
#         anyone   -8.3244
#        anybody   -7.9018
#      everybody   -7.7617
#          there   -7.5989
#             we   -7.3606
#        Grayson   -7.3602
#             it   -6.9409
#       stuffing   -6.9080
# #####################################14###########################
# Top 10 ↑ logit changes:
#             >.   +9.3079
#             $.   +8.7889
#            ../   +8.3286
#              ■   +8.2987
#            etc   +7.9271
#             /.   +7.8141
#             ••   +7.7765
#          Found   +7.6643
#             mp   +7.6402
#             \.   +7.6357
#
# Top 10 ↓ logit changes:
#        analogy   -7.4274
#             's   -7.1836
#       everyone   -7.1400
#           sums   -7.1277
#    cryptocurrencies   -6.9869
#          aside   -6.8940
#       atheists   -6.8533
#           most   -6.7485
#        bitcoin   -6.6995
#         people   -6.6933
# #####################################15###########################
# Top 10 ↑ logit changes:
#         retard   +7.3262
#              s   +6.8648
#             zz   +6.7767
#          bitch   +6.7588
#            nut   +6.7346
#           head   +6.5930
#           shit   +6.5165
#       retarded   +6.4329
#         fuckin   +6.3897
#           cunt   +6.3756
#
# Top 10 ↓ logit changes:
#    Transparency   -6.1994
#    cryptocurrencies   -6.1855
#        Mozilla   -6.0285
#      Mormonism   -5.7070
#          React   -5.6128
#      Microsoft   -5.5655
#    implementing   -5.4707
#       adopting   -5.3822
#          Scala   -5.3402
#     discussing   -5.3110
# #####################################16###########################
# Top 10 ↑ logit changes:
#              く   +9.4009
#             の�   +9.0533
#          Notes   +8.8921
#    Description   +8.7612
#    --------------------   +8.7557
#    ----------------   +8.7137
#            (%)   +8.6867
#         Korean   +8.4557
#      Available   +8.3462
#              �   +8.2244
#
# Top 10 ↓ logit changes:
#        insofar   -8.5234
#     legalizing   -8.2550
#         anyone   -8.1367
#    contradicts   -8.0637
#        anybody   -7.7687
#        whoever   -7.7388
#             we   -7.5604
#          there   -7.5299
#         owning   -7.4036
#      justifies   -7.3537
# #####################################17###########################
# Top 10 ↑ logit changes:
#           Like   +10.2881
#           Like   +9.7968
#           like   +8.8927
#           hare   +8.2432
#            lik   +7.8796
#          Likes   +7.7420
#           LIKE   +7.6283
#             LI   +7.3964
#          SHARE   +7.1312
#      subscribe   +7.0058
#
# Top 10 ↓ logit changes:
#          Schne   -6.6059
#    establishing   -6.4263
#      justifies   -6.1743
#        settles   -6.1580
#             's   -6.1552
#            CCP   -6.0224
#         Turing   -5.8868
#        Satoshi   -5.8654
#    psychologists   -5.7228
#      qualifies   -5.7183
# #####################################18###########################
# Top 10 ↑ logit changes:
#             to   +11.9209
#             TO   +11.2865
#           onto   +10.5501
#            tto   +10.5330
#            dos   +10.4112
#             vi   +10.2842
#             vt   +10.1777
#             vu   +9.6025
#             vo   +9.5949
#             do   +9.4354
#
# Top 10 ↓ logit changes:
#      justifies   -7.5960
#     legalizing   -7.4856
#          Schne   -7.3686
#       Sessions   -7.3593
#         Grimes   -7.3302
#           Gins   -7.3173
#      qualifies   -7.2915
#       Scarlett   -7.1563
#      Rosenberg   -7.1561
#        Feldman   -7.1419
# #####################################19###########################
# Top 10 ↑ logit changes:
#          Offer   +11.2818
#          offer   +10.1164
#          offer   +9.3277
#         expire   +8.7134
#             :{   +8.2030
#       Purchase   +7.9996
#        expires   +7.7773
#      available   +7.7260
#    Description   +7.5694
#        Subject   +7.4154
#
# Top 10 ↓ logit changes:
#         Grimes   -7.9978
#       everyone   -6.7734
#      everybody   -6.6993
#        whoever   -6.6896
#         Hindus   -6.5896
#           Gabe   -6.5868
#          Lange   -6.5404
#          Gavin   -6.5113
#       atheists   -6.5110
#           Milo   -6.4745
# #####################################20###########################
# Top 10 ↑ logit changes:
#           Narr   +9.1690
#          Story   +7.8257
#        telling   +7.7554
#         EVENTS   +7.4025
#        Feature   +7.1905
#          story   +6.8351
#              �   +6.7039
#       narrated   +6.6673
#     Characters   +6.5794
#           ":{"   +6.5235
#
# Top 10 ↓ logit changes:
#       everyone   -6.2183
#       Bethesda   -6.0768
#     legalizing   -6.0575
#          Rocks   -5.8953
#        whoever   -5.8074
#        someday   -5.7560
#    libertarians   -5.6944
#       Blizzard   -5.6636
#       atheists   -5.6314
#           Dill   -5.6191
# #####################################21###########################
# Top 10 ↑ logit changes:
#        Azerbai   +11.4646
#      Bulgarian   +10.8173
#       Armenian   +10.1849
#         Arabic   +9.7320
#              �   +9.4755
#          Gujar   +9.4702
#    ----------------   +9.4661
#            Bul   +9.3088
#        Persian   +9.2677
#           Arab   +9.2175
#
# Top 10 ↓ logit changes:
#           Robb   -9.0558
#         Ramsey   -8.4909
#        Robbins   -8.4093
#          Tyler   -8.3841
#       everyone   -8.0790
#          Riley   -8.0425
#           reth   -7.9482
#       Scarlett   -7.9396
#    libertarians   -7.8850
#        Watkins   -7.7613
# #####################################22###########################
# Top 10 ↑ logit changes:
#        Writing   +10.5068
#        writing   +8.7233
#        Editing   +8.5997
#          Pages   +8.0347
#        Writing   +8.0039
#          Voice   +7.3396
#          liter   +7.3251
#     Characters   +7.2600
#        letters   +7.2373
#        Written   +7.2298
#
# Top 10 ↓ logit changes:
#       everyone   -6.7009
#        settles   -6.4558
#           Dill   -6.4257
#        Satoshi   -6.3670
#             's   -6.2401
#          Valve   -6.1186
#           Gabe   -6.0686
#    libertarians   -6.0186
#      everybody   -5.9398
#           Levi   -5.8137
# #####################################23###########################
# Top 10 ↑ logit changes:
#         German   +9.1908
#         German   +8.9148
#            ese   +8.4790
#        Spanish   +7.7474
#        Spanish   +7.6191
#        Italian   +7.6098
#         EVENTS   +7.5909
#    Description   +7.5236
#      Available   +7.4577
#      Hungarian   +7.4232
#
# Top 10 ↓ logit changes:
#       everyone   -8.1297
#          aside   -7.9202
#          there   -7.9002
#      photograp   -7.8210
#         anyone   -7.3663
#    introducing   -7.2965
#      everybody   -7.1622
#       exposing   -7.1524
#        whoever   -7.0637
#           what   -7.0282
# #####################################24###########################
# Top 10 ↑ logit changes:
#         ournal   +1.1231
#            gui   +1.1013
#           peer   +1.0718
#    implementations   +1.0647
#          earch   +1.0643
#             ie   +1.0424
#             ff   +1.0419
#             js   +1.0381
#       features   +1.0358
#        Offline   +1.0123
#
# Top 10 ↓ logit changes:
#           sums   -1.4421
#         summed   -1.0844
#          motto   -1.0589
#          wraps   -1.0526
#            rhy   -1.0033
#         Alaska   -1.0018
#    Thanksgiving   -0.9993
#            iba   -0.9971
#         Costco   -0.9864
#      concludes   -0.9781
# #####################################25###########################
# Top 10 ↑ logit changes:
#         Modern   +10.5482
#         modern   +10.0233
#     industrial   +8.4685
#          ature   +8.1360
#        Classic   +7.6807
#         Americ   +7.6375
#    Contemporary   +7.6240
#        classic   +7.2850
#        century   +7.2453
#           chic   +7.0921
#
# Top 10 ↓ logit changes:
#       everyone   -7.7661
#      everybody   -7.5499
#          there   -7.1537
#      comparing   -6.9538
#             if   -6.7024
#         Arpaio   -6.6008
#        Senator   -6.4581
#     mentioning   -6.4480
#             's   -6.3179
#          Sagan   -6.3082
# #####################################26###########################
# Top 10 ↑ logit changes:
#          conom   +1.3545
#            aum   +1.2657
#           Hume   +1.1910
#           Narr   +1.1486
#           Marx   +1.1379
#          Leary   +1.1348
#         arcity   +1.1176
#           Marx   +1.1094
#         ournal   +1.0876
#        aterial   +1.0709
#
# Top 10 ↓ logit changes:
#          wraps   -1.5506
#           sums   -1.5409
#         sucker   -1.3296
#      countdown   -1.2852
#        settles   -1.2768
#     disclaimer   -1.2346
#           begs   -1.2338
#         outfit   -1.2132
#           rant   -1.1960
#           list   -1.1937
# #####################################27###########################
# Top 10 ↑ logit changes:
#         Unique   +14.4582
#         unique   +12.8858
#       Uncommon   +9.7710
#        Special   +9.2185
#        special   +9.1056
#             Un   +9.0392
#         Custom   +8.9712
#        Feature   +8.9635
#      Different   +8.6409
#    Description   +8.5674
#
# Top 10 ↓ logit changes:
#          Gavin   -7.8847
#           Milo   -7.5869
#          Geoff   -7.4724
#          Micha   -7.3894
#        Satoshi   -7.1489
#           Karl   -7.0692
#             's   -6.9754
#          there   -6.9403
#        Quentin   -6.9050
#       everyone   -6.8706
# #####################################28###########################
# Top 10 ↑ logit changes:
#             KA   +12.8703
#             FK   +12.7495
#             IK   +12.6051
#             KI   +11.9787
#             KK   +11.7468
#             KR   +11.6492
#              K   +11.5325
#            KER   +11.2501
#             KE   +10.9158
#             AK   +10.7007
#
# Top 10 ↓ logit changes:
#       atheists   -8.1347
#           most   -7.6715
#           sums   -7.3206
#        analogy   -6.9450
#        Satoshi   -6.8047
#       everyone   -6.7487
#        atheism   -6.7165
#           many   -6.6882
#        bitcoin   -6.5438
#        pairing   -6.4849
# #####################################29###########################
# Top 10 ↑ logit changes:
#        reflect   +11.8038
#        reflect   +10.0636
#        Reflect   +9.2043
#     illuminate   +7.7594
#           emit   +7.6705
#        Feature   +7.5291
#    guiActiveUnfocused   +7.3232
#        amplify   +7.1767
#         EVENTS   +7.1258
#      reflected   +6.9811
#
# Top 10 ↓ logit changes:
#       quitting   -7.2610
#        Assange   -7.0180
#      GamerGate   -6.8337
#        Manning   -6.7273
#          tying   -6.7269
#     Stephenson   -6.6999
#        handing   -6.6540
#         ending   -6.6192
#        anybody   -6.5970
#    libertarians   -6.5888
# #####################################30###########################
# Top 10 ↑ logit changes:
#            out   +6.8585
#          ifier   +6.6856
#           tube   +6.2154
#          Pages   +6.1332
#             ->   +6.0545
#          Label   +6.0027
#          ition   +5.9278
#            ium   +5.9153
#            -->   +5.9082
#            ale   +5.9031
#
# Top 10 ↓ logit changes:
#            Zin   -5.6535
#          Truth   -5.4860
#         Ashton   -5.4416
#     Sutherland   -5.4117
#          ynski   -5.3324
#    interpreting   -5.2961
#    criticizing   -5.2911
#        Judaism   -5.2491
#      Mormonism   -5.2400
#    acknowledging   -5.1914
# #####################################31###########################
# Top 10 ↑ logit changes:
#           Lear   +11.4483
#       Learning   +11.4369
#          learn   +10.6092
#       learning   +10.5369
#          Learn   +10.1780
#           lear   +9.0341
#           Know   +8.7434
#           lear   +8.4633
#          Adapt   +8.4034
#          Adult   +7.9901
#
# Top 10 ↓ logit changes:
#          Valve   -7.1971
#             's   -6.7939
#        Satoshi   -6.7776
#          Kanye   -6.7536
#        Warrant   -6.4247
#          Micha   -6.3730
#        Spencer   -6.3707
#        settles   -6.3631
#          Gavin   -6.3332
#             JJ   -6.3293
# #####################################32###########################
# Top 10 ↑ logit changes:
#         global   +11.4965
#         Global   +10.3139
#        contact   +8.9225
#        network   +8.9033
#      available   +8.8615
#          local   +8.6896
#   international   +8.6519
#          multi   +8.4343
#          Found   +8.4340
#        default   +8.3985
#
# Top 10 ↓ logit changes:
#             's   -7.0323
#         Clause   -6.8760
#          Scala   -6.6820
#           Gabe   -6.6504
#        Passage   -6.4467
#        analogy   -6.3710
#          there   -6.3595
#         Levine   -6.3582
#          Morty   -6.2835
#          Valve   -6.2473
# #####################################33###########################
# Top 10 ↑ logit changes:
#             ."   +8.1350
#            and   +7.7826
#            etc   +7.4934
#             &&   +7.4526
#           Then   +7.4494
#             &&   +7.3444
#            And   +7.3368
#           ands   +7.2559
#            yet   +7.2139
#            AND   +7.1904
#
# Top 10 ↓ logit changes:
#             's   -5.6397
#         Grimes   -5.4451
#        modesty   -5.2953
#         phrase   -5.2220
#         merits   -5.1746
#    characterization   -5.1444
#      Rasmussen   -5.1333
#        analogy   -5.1289
#         superf   -5.0990
#    Hearthstone   -5.0759
# #####################################34###########################
# Top 10 ↑ logit changes:
#       Provides   +12.2966
#        Provide   +10.8589
#           Prov   +10.2091
#        provide   +9.2443
#       provides   +9.0188
#           prov   +8.5744
#       Provided   +8.5313
#         Allows   +8.3533
#          afety   +8.3035
#     implements   +8.0231
#
# Top 10 ↓ logit changes:
#            isu   -7.0402
#      Nietzsche   -6.9667
#           Bett   -6.7486
#           Buch   -6.6162
#          Kanye   -6.6118
#        Mandela   -6.5150
#        hurting   -6.4375
#          Adolf   -6.4277
#     negativity   -6.3837
#           Joey   -6.3806
# #####################################35###########################
# Top 10 ↑ logit changes:
#    Description   +9.9171
#    Description   +8.8638
#         blends   +8.5535
#          lings   +8.3964
#          blend   +8.2579
#          aroma   +8.2252
#            een   +8.1037
#        Tobacco   +7.9508
#            tob   +7.8036
#         Smooth   +7.7305
#
# Top 10 ↓ logit changes:
#    Yiannopoulos   -8.1141
#           iHUD   -8.1098
#            龍喚士   -7.6756
#         Drupal   -7.6202
#      GamerGate   -7.5608
#       Ethereum   -7.3094
#        Gorsuch   -7.2263
#     blockchain   -7.1961
#        systemd   -7.1939
#     Blockchain   -7.0530
# #####################################36###########################
# Top 10 ↑ logit changes:
#           ngth   +7.1747
#         lively   +7.0307
#          atile   +6.7145
#         EVENTS   +6.6232
#         Strong   +6.4492
#        Enabled   +6.4467
#          activ   +6.2877
#        vibrant   +6.1955
#       vitality   +6.1517
#            Its   +6.1005
#
# Top 10 ↓ logit changes:
#          Fritz   -6.1814
#           Schn   -6.0981
#       Bethesda   -6.0783
#         Django   -5.9673
#       wrapping   -5.9252
#           Kers   -5.8003
#        Bitcoin   -5.7318
#         Gibson   -5.6818
#         Pebble   -5.6719
#      comparing   -5.6425
# #####################################37###########################
# Top 10 ↑ logit changes:
#        diverse   +9.6751
#         incent   +9.1277
#           vary   +8.9570
#       disperse   +7.8853
#       converge   +7.7420
#      integrate   +7.7343
#       innovate   +7.5514
#         varied   +7.5109
#         differ   +7.3927
#    differentiate   +7.3778
#
# Top 10 ↓ logit changes:
#        Quentin   -7.1530
#            was   -6.8348
#             's   -6.6979
#        Randall   -6.3502
#           Zack   -6.3399
#        Bentley   -6.2940
#         Werner   -6.2743
#          Jenny   -6.2324
#           Nate   -6.2166
#             JJ   -6.1700
# #####################################38###########################
# Top 10 ↑ logit changes:
#          isine   +10.4938
#           dain   +9.4296
#            eur   +9.3330
#          ateur   +8.5753
#           oeuv   +8.3532
#        cuisine   +8.2963
#          eater   +8.1406
#         ourmet   +8.0783
#    Ingredients   +7.8665
#         ournal   +7.6578
#
# Top 10 ↓ logit changes:
#     legalizing   -7.1264
#         Turing   -7.0486
#       everyone   -7.0146
#        Mandela   -6.6664
#           Milo   -6.6361
#    libertarians   -6.6146
#           this   -6.6108
#          Ashes   -6.5989
#     mentioning   -6.5850
#       atheists   -6.5761
# #####################################39###########################
# Top 10 ↑ logit changes:
#           deep   +10.1687
#           Deep   +9.5470
#           thro   +8.8930
#           ened   +8.6341
#           thro   +8.0151
#           down   +7.8271
#         depths   +7.7339
#           ngth   +7.6061
#          sleep   +7.4661
#           dark   +7.4548
#
# Top 10 ↓ logit changes:
#          Micha   -7.0266
#     legalizing   -6.9561
#      comparing   -6.8718
#    introducing   -6.7721
#            Zac   -6.7605
#       everyone   -6.3245
#       Motorola   -6.2829
#         naming   -6.2621
#         Tucker   -6.1813
#          Valve   -6.1746
# #####################################40###########################
# Top 10 ↑ logit changes:
#          liter   +9.4439
#     Literature   +9.4311
#          Liter   +9.1265
#     literature   +7.9843
#       reviewed   +7.9004
#          liter   +7.8541
#        fiction   +7.4881
#       literary   +7.2519
#         ournal   +7.0384
#      Published   +6.7868
#
# Top 10 ↓ logit changes:
#           Gabe   -6.9067
#       everyone   -6.7974
#          Gavin   -6.7956
#         Pebble   -6.7403
#         Garmin   -6.5033
#          Valve   -6.4090
#         Ultron   -6.2634
#            Zac   -6.1815
#       Coinbase   -6.1746
#        Canaver   -6.1706
# #####################################41###########################
# Top 10 ↑ logit changes:
#      Influence   +9.5684
#         impact   +9.2179
#      influence   +8.7896
#         incent   +7.8589
#            Imp   +7.7503
#           ngth   +7.4581
#         origin   +7.4513
#           hift   +7.1950
#       Increase   +6.8932
#        effects   +6.8373
#
# Top 10 ↓ logit changes:
#             's   -6.6510
#       everyone   -6.6443
#      everybody   -6.4723
#          there   -6.3724
#       atheists   -6.1906
#        Sanders   -6.1164
#           Zack   -6.0481
#          maybe   -6.0351
#             we   -6.0132
#            Zen   -5.8717
# #####################################42###########################
# Top 10 ↑ logit changes:
#           film   +9.3731
#           Film   +8.0153
#      projector   +7.9916
#       levision   +7.9335
#          flick   +7.7155
#        Feature   +7.6544
#        theater   +7.5310
#        theatre   +7.4372
#         Indust   +7.3939
#          movie   +7.3863
#
# Top 10 ↓ logit changes:
#       everyone   -7.3772
#           sums   -7.2108
#        whoever   -7.0695
#          there   -6.4968
#         arming   -6.3674
#      everybody   -6.2919
#           Gors   -6.2140
#          Morty   -6.1859
#          Mongo   -6.1661
#            byn   -6.1378
# #####################################43###########################
# Top 10 ↑ logit changes:
#     expression   +11.1758
#     Expression   +10.2872
#    Description   +9.8139
#           expr   +9.7888
#              {   +9.2645
#           Name   +9.1568
#             ({   +9.1230
#      Attribute   +9.0942
#             {}   +9.0574
#       operator   +9.0494
#
# Top 10 ↓ logit changes:
#         Cullen   -8.3748
#         Ridley   -8.3686
#          Scott   -7.8141
#          Bryce   -7.5616
#        Goddard   -7.3536
#         Grimes   -7.3389
#       everyone   -7.1176
#           Gunn   -6.9602
#       Hannibal   -6.8984
#         Madden   -6.8294
# #####################################44###########################
# Top 10 ↑ logit changes:
#     neoliberal   +1.7176
#     liberalism   +1.5286
#           prag   +1.5075
#        Marxism   +1.4985
#           Hume   +1.4263
#      anarchism   +1.4126
#        ecology   +1.3921
#    globalization   +1.3905
#           Marx   +1.3900
#          earch   +1.3790
#
# Top 10 ↓ logit changes:
#          wraps   -1.7342
#           sums   -1.7135
#        settles   -1.6076
#         outfit   -1.4723
#         covers   -1.4644
#           list   -1.4516
#      countdown   -1.4482
#        picture   -1.4290
#         teaser   -1.4130
#           lapt   -1.3518
# #####################################45###########################
# Top 10 ↑ logit changes:
#             so   +10.7582
#             ss   +10.4443
#            sbm   +10.4004
#             df   +10.3421
#             sb   +9.9731
#            sed   +9.9681
#             bb   +9.9566
#             ]"   +9.8477
#            sid   +9.7572
#             mp   +9.6423
#
# Top 10 ↓ logit changes:
#       Ethereum   -7.3385
#       everyone   -7.1877
#         Cornel   -7.0650
#            CCP   -6.8867
#         Oculus   -6.8691
#     Constantin   -6.8507
#    astronomers   -6.8439
#            Kro   -6.7654
#    objectively   -6.7415
#    cryptocurrencies   -6.6867
# #####################################46###########################
# Top 10 ↑ logit changes:
#     neoliberal   +1.2370
#          conom   +1.1189
#        Marxism   +1.0727
#           Marx   +1.0277
#     liberalism   +0.9989
#           geop   +0.9824
#           alth   +0.9655
#    revolutionaries   +0.9550
#         Bolshe   +0.9381
#         pessim   +0.9326
#
# Top 10 ↓ logit changes:
#          wraps   -1.2604
#        settles   -1.2569
#           begs   -1.2193
#           sums   -1.0716
#          recip   -1.0676
#          scarf   -0.9621
#      qualifies   -0.9498
#          ursed   -0.9471
#           Kids   -0.9317
#           bisc   -0.9302
# #####################################47###########################
# Top 10 ↑ logit changes:
#          Union   +10.7661
#    Organisation   +9.3730
#       Economic   +9.3049
#     Additional   +9.3035
#    Organization   +9.1177
#       Regional   +8.8099
#          Asian   +8.7459
#        Affairs   +8.7036
#         Compet   +8.6706
#       External   +8.4054
#
# Top 10 ↓ logit changes:
#     legalizing   -8.5327
#            pim   -7.7297
#          rosse   -7.6855
#         Grimes   -7.5347
#         advice   -7.5054
#           lett   -7.4478
#        analogy   -7.4345
#         convol   -7.3621
#         Weiner   -7.3386
#     Blumenthal   -7.3185
# #####################################48###########################
# Top 10 ↑ logit changes:
#        History   +10.5672
#        history   +10.3114
#         ISTORY   +8.8424
#           NEWS   +8.6648
#           hist   +8.1787
#         origin   +7.9785
#        History   +7.8255
#          learn   +7.7721
#           high   +7.5944
#           Hist   +7.4720
#
# Top 10 ↓ logit changes:
#          Valve   -7.9890
#          Ember   -6.8178
#           Gabe   -6.6913
#       everyone   -6.6284
#          Flake   -6.5986
#          Rover   -6.4935
#        Satoshi   -6.3201
#        Clojure   -6.3127
#             Ce   -6.2385
#        whoever   -6.2345
# #####################################49###########################
# Top 10 ↑ logit changes:
#           Form   +11.2822
#           form   +10.0264
#           form   +8.2965
#           Name   +8.2048
#       Contents   +8.1615
#            ://   +8.0629
#          ature   +7.9396
#          Field   +7.9259
#           ":{"   +7.8883
#        Element   +7.8812
#
# Top 10 ↓ logit changes:
#       everyone   -8.6768
#      everybody   -8.1850
#          Gavin   -7.3626
#        Quentin   -7.2375
#        Perkins   -6.8795
#          Kanye   -6.8052
#         Laurie   -6.7961
#           Milo   -6.7805
#           Jeff   -6.7481
#        anybody   -6.6269
